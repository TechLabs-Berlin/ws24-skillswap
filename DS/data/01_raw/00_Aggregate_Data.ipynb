# %%
import pandas as pd

# %%
# Import DataFrames from CSV files
Personal_Info = pd.read_csv('Personal_Info.csv')
Skill_Exchange = pd.read_csv('Skill_Exchange.csv')
Track_Record = pd.read_csv('Track_Record.csv')
Feedback = pd.read_csv('Feedback.csv')


# Concatenate DataFrames horizontally
combined_df = pd.concat([Personal_Info, Skill_Exchange, Track_Record, Feedback], axis=1)

combined_df.head()
# Out:
#    First_Name                           EMail  Age  Gender  \
# 0   Tymoteusz      tymoteusz.murray@gmail.com   51   Other
# 1  Anne-Marie     anne-marie.guarato@mail.com   27    Male
# 2    Nazlihan  nazlihan.littizzetto@yahoo.com   42  Female
# 3     Carmelo         carmelo.babato@arcor.de   58    Male
# 4    Tutkucan       tutkucan.karge@icloud.com   55   Other
#
#   Location_Preferences                                Coordinate  Country  \
# 0           Local Only    (52.61055179270523, 13.21377580760253)  Germany
# 1           Local Only  (52.411841312390216, 13.754020527691711)  Germany
# 2      Local or Remote   (52.46021525312517, 13.289798400558723)  Germany
# 3          Remote Only    (52.67290557991128, 13.13237868754457)  Germany
# 4          Remote Only    (52.58955980655409, 13.29518537953884)  Germany
#
#      City                                Languages_Preferred       Last_Seen  \
# 0  Berlin  ['Turkish', 'Portuguese', 'Bengali', 'French',...       Yesterday
# 1  Berlin  ['Bengali', 'Mandarin Chinese', 'Japanese', 'G...   Within a Week
# 2  Berlin                  ['English', 'Romanian', 'French']  Within a Month
# 3  Berlin  ['Romanian', 'Polish', 'Russian', 'English', '...        Recently
# 4  Berlin  ['English', 'Polish', 'Ukrainian', 'Japanese',...   Within a Week
#
#    ... Self_Defense_and_Personal_Safety_dem Healthcare_and_Nutrition_dem  \
# 0  ...                               Expert                     Advanced
# 1  ...                             Advanced                       Novice
# 2  ...                               Novice                     Advanced
# 3  ...                               Novice                       Novice
# 4  ...                               Novice                     Advanced
#
#   Count_Skills_Rec Count_Skills_Off Rec_to_Off_Ratio           Usability  \
# 0              169              184             0.92  Neutral or Average
# 1               40               42             0.95      Very Satisfied
# 2              118              100             1.18   Very Dissatisfied
# 3               83               68             1.22  Neutral or Average
# 4              142              152             0.93        Dissatisfied
#
#     Speed_Performance Feature_Satisfaction Security_Satisfaction  \
# 0   Very Dissatisfied         Dissatisfied          Dissatisfied
# 1  Neutral or Average         Dissatisfied             Satisfied
# 2           Satisfied    Very Dissatisfied        Very Satisfied
# 3  Neutral or Average   Neutral or Average        Very Satisfied
# 4   Very Dissatisfied    Very Dissatisfied          Dissatisfied
#
#      Customer_Support
# 0        Dissatisfied
# 1   Very Dissatisfied
# 2        Dissatisfied
# 3  Neutral or Average
# 4      Very Satisfied
#
# [5 rows x 97 columns]

# %%
combined_df.to_csv('Skillswap_Data_Raw.csv', index=False)
