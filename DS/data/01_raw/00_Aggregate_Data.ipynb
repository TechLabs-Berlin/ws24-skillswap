# %%
import pandas as pd

# %%
Personal_Info = pd.read_csv('Personal_Info.csv')
Skill_Exchange = pd.read_csv('Skill_Exchange.csv')
Track_Record = pd.read_csv('Track_Record.csv')
Feedback = pd.read_csv('Feedback.csv')

# Concatenate DataFrames horizontally
combined_df = pd.concat([Personal_Info, Skill_Exchange, Track_Record, Feedback], axis=1)

combined_df.head(750)
# Out:
#       First_Name                          EMail  Age             Gender  \
# 0          Avunç            avunç.santos@web.de   23               Male
# 1       Özüdoğru         özüdoğru.ossola@gmx.de   26  Prefer not to say
# 2       Vittorio       vittorio.kamela@1und1.de   28               Male
# 3      Tymoteusz      tymoteusz.beyer@yahoo.com   28  Prefer not to say
# 4        Melissa    melissa.antunes@outlook.com   27  Prefer not to say
# ..           ...                            ...  ...                ...
# 745      Durante   durante.phillips@t-online.de   29             Female
# 746        Aimée      aimée.burcardo@freenet.de   29               Male
# 747         Yara      yara.mazzanti@unitybox.de   26               Male
# 748        Nanni              nanni.mary@web.de   25             Female
# 749  Luis Miguel  luis miguel.robinson@arcor.de   29            Diverse
#
#     Location_Preferences                                Coordinate  Country  \
# 0        Local or Remote  (52.403010937141616, 13.536818568223497)  Germany
# 1            Remote Only   (52.39643123462186, 13.478119345675024)  Germany
# 2        Local or Remote   (52.35074370232088, 13.737720404874722)  Germany
# 3        Local or Remote  (52.514799224781996, 13.682851320445437)  Germany
# 4        Local or Remote   (52.41444021788198, 13.493164763748588)  Germany
# ..                   ...                                       ...      ...
# 745      Local or Remote  (52.606941950125574, 13.122216082424494)  Germany
# 746      Local or Remote  (52.338605999465656, 13.509260472409672)  Germany
# 747           Local Only   (52.67204553460524, 13.716217612376095)  Germany
# 748          Remote Only    (52.612855605922014, 13.1837475602305)  Germany
# 749      Local or Remote   (52.62123506680054, 13.501557815343164)  Germany
#
#        City                                Languages_Preferred  \
# 0    Berlin  ['Spanish', 'Mandarin Chinese', 'Hindi', 'Poli...
# 1    Berlin  ['Arabic', 'Romanian', 'Polish', 'French', 'Ge...
# 2    Berlin  ['German', 'Turkish', 'Bengali', 'Mandarin Chi...
# 3    Berlin  ['Ukrainian', 'Portuguese', 'Spanish', 'Turkish']
# 4    Berlin                              ['French', 'Turkish']
# ..      ...                                                ...
# 745  Berlin               ['Punjabi', 'Italian', 'Portuguese']
# 746  Berlin  ['Bengali', 'Turkish', 'Mandarin Chinese', 'Pu...
# 747  Berlin                              ['Punjabi', 'French']
# 748  Berlin                              ['Arabic', 'Spanish']
# 749  Berlin                    ['Arabic', 'Bengali', 'German']
#
#             Last_Seen  ... Self_Defense_and_Personal_Safety_dem  \
# 0       Within a Week  ...                                  NaN
# 1       Within a Week  ...                             Advanced
# 2    Over a Month Ago  ...                                  NaN
# 3       Within a Week  ...                         Intermediate
# 4       Within a Week  ...                             Beginner
# ..                ...  ...                                  ...
# 745     Within a Week  ...                             Beginner
# 746     Within a Week  ...                                  NaN
# 747          Recently  ...                               Expert
# 748          Recently  ...                             Advanced
# 749         Yesterday  ...                                  NaN
#
#     Healthcare_and_Nutrition_dem Count_Skills_Rec Count_Skills_Off  \
# 0                            NaN              169              184
# 1                         Expert               40               42
# 2                            NaN              118              100
# 3                         Novice               83               68
# 4                         Expert              142              152
# ..                           ...              ...              ...
# 745                 Intermediate              112              128
# 746                          NaN              237              196
# 747                       Expert               98               85
# 748                     Advanced              111               99
# 749                          NaN              118              102
#
#     Rec_to_Off_Ratio           Usability   Speed_Performance  \
# 0               0.92      Very Satisfied        Dissatisfied
# 1               0.95      Very Satisfied        Dissatisfied
# 2               1.18           Satisfied  Neutral or Average
# 3               1.22           Satisfied           Satisfied
# 4               0.93  Neutral or Average      Very Satisfied
# ..               ...                 ...                 ...
# 745             0.88           Satisfied  Neutral or Average
# 746             1.21  Neutral or Average      Very Satisfied
# 747             1.15           Satisfied        Dissatisfied
# 748             1.12      Very Satisfied  Neutral or Average
# 749             1.16        Dissatisfied        Dissatisfied
#
#     Feature_Satisfaction Security_Satisfaction    Customer_Support
# 0         Very Satisfied     Very Dissatisfied        Dissatisfied
# 1      Very Dissatisfied             Satisfied  Neutral or Average
# 2              Satisfied     Very Dissatisfied  Neutral or Average
# 3         Very Satisfied    Neutral or Average      Very Satisfied
# 4     Neutral or Average     Very Dissatisfied  Neutral or Average
# ..                   ...                   ...                 ...
# 745    Very Dissatisfied             Satisfied           Satisfied
# 746    Very Dissatisfied          Dissatisfied  Neutral or Average
# 747       Very Satisfied        Very Satisfied        Dissatisfied
# 748   Neutral or Average        Very Satisfied   Very Dissatisfied
# 749   Neutral or Average             Satisfied        Dissatisfied
#
# [750 rows x 97 columns]

# %%
combined_df.to_csv('Skillswap_Data_Raw.csv', index=False)
