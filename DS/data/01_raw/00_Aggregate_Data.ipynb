# %%
import pandas as pd

# %%
# Import DataFrames from CSV files
Personal_Info = pd.read_csv('Personal_Info.csv')
Skill_Exchange = pd.read_csv('Skill_Exchange.csv')
Track_Record = pd.read_csv('Track_Record.csv')
Feedback = pd.read_csv('Feedback.csv')


# Concatenate DataFrames horizontally
combined_df = pd.concat([Personal_Info, Skill_Exchange, Track_Record, Feedback], axis=1)

combined_df.head()
# Out:
#   First_Name                        EMail  Age  Gender  \
# 0      Wanda         wanda.opizzi@aol.com   46    Male
# 1    Meinrad  meinrad.kiedrowicz@zoho.com   26   Other
# 2     Derkay    derkay.kurach@outlook.com   41    Male
# 3      Uzsoy     uzsoy.akdeniz@freenet.de   54    Male
# 4      Alpsü     alpsü.demirel@icloud.com   19  Female
#
#                                  Coordinate  Country    City  \
# 0   (52.48592054317992, 13.597034412185927)  Germany  Berlin
# 1   (52.59690466818614, 13.725347983308117)  Germany  Berlin
# 2    (52.56108833495195, 13.18563761680123)  Germany  Berlin
# 3  (52.443532336864735, 13.419956868448828)  Germany  Berlin
# 4    (52.36608543756369, 13.10990718388389)  Germany  Berlin
#
#                                  Languages_Preferred         Last_Seen  \
# 0  ['English', 'Italian', 'Ukrainian', 'Turkish '...  Over a Month Ago
# 1         ['German', 'Punjabi', 'Spanish', 'Arabic']     Within a Week
# 2                              ['Hindi', 'Japanese']     Within a Week
# 3                                       ['Romanian']     Within a Week
# 4  ['Arabic', 'Portuguese', 'Mandarin Chinese', '...     Within a Week
#
#      Response_Time  ... Self_Defense_and_Personal_Safety_dem  \
# 0    Within a week  ...                               Expert
# 1  Within 24 hours  ...                             Advanced
# 2  Within 24 hours  ...                               Novice
# 3  Within 24 hours  ...                               Novice
# 4   Within a month  ...                               Novice
#
#   Healthcare_and_Nutrition_dem Count_Skills_Rec Count_Skills_Off  \
# 0                     Advanced              169              184
# 1                       Novice               40               42
# 2                     Advanced              118              100
# 3                       Novice               83               68
# 4                     Advanced              142              152
#
#   Rec_to_Off_Ratio           Usability   Speed_Performance  \
# 0             0.92  Neutral or Average   Very Dissatisfied
# 1             0.95      Very Satisfied  Neutral or Average
# 2             1.18   Very Dissatisfied           Satisfied
# 3             1.22  Neutral or Average  Neutral or Average
# 4             0.93        Dissatisfied   Very Dissatisfied
#
#   Feature_Satisfaction Security_Satisfaction    Customer_Support
# 0         Dissatisfied          Dissatisfied        Dissatisfied
# 1         Dissatisfied             Satisfied   Very Dissatisfied
# 2    Very Dissatisfied        Very Satisfied        Dissatisfied
# 3   Neutral or Average        Very Satisfied  Neutral or Average
# 4    Very Dissatisfied          Dissatisfied      Very Satisfied
#
# [5 rows x 96 columns]

# %%
combined_df.to_csv('Skillswap_Data_Raw.csv', index=False)
