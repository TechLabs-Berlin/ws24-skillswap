# %%
import pandas as pd

# %%
# Import DataFrames from CSV files
Personal_Info = pd.read_csv('Personal_Info.csv')
Skill_Exchange = pd.read_csv('Skill_Exchange.csv')
Track_Record = pd.read_csv('Track_Record.csv')
Feedback = pd.read_csv('Feedback.csv')


# Concatenate DataFrames horizontally
combined_df = pd.concat([Personal_Info, Skill_Exchange, Track_Record, Feedback], axis=1)

combined_df.head()
# Out:
#   First_Name                      EMail  Age Gender Location_Preferences  \
# 0       Kyle        kyle.akar@yahoo.com   47   Male           Local Only
# 1    Atilhan  atilhan.bigot@unitybox.de   23   Male          Remote Only
# 2   Rosemary    rosemary.correia@gmx.de   39   Male           Local Only
# 3      Filip     filip.tenorio@zoho.com   37  Other      Local or Remote
# 4      Danny     danny.launay@yahoo.com   64   Male          Remote Only
#
#                                  Coordinate  Country    City  \
# 0  (52.501831701039016, 13.646481042226515)  Germany  Berlin
# 1   (52.55628485036743, 13.686748262229765)  Germany  Berlin
# 2  (52.579470246526284, 13.429777806127676)  Germany  Berlin
# 3    (52.44735217775999, 13.74549808567323)  Germany  Berlin
# 4  (52.382426328031976, 13.659678412444189)  Germany  Berlin
#
#                                  Languages_Preferred       Last_Seen  ...  \
# 0  ['Hindi', 'Portuguese', 'Italian', 'Punjabi', ...           Today  ...
# 1  ['Bengali', 'Hindi', 'Polish', 'Arabic', 'Span...       Yesterday  ...
# 2  ['Ukrainian', 'Hindi', 'Punjabi', 'Mandarin Ch...           Today  ...
# 3  ['Italian', 'Mandarin Chinese', 'Hindi', 'Ukra...  Within a Month  ...
# 4  ['English', 'Ukrainian', 'German', 'Japanese',...        Recently  ...
#
#   Self_Defense_and_Personal_Safety_dem Healthcare_and_Nutrition_dem  \
# 0                               Expert                     Advanced
# 1                             Advanced                       Novice
# 2                               Novice                     Advanced
# 3                               Novice                       Novice
# 4                               Novice                     Advanced
#
#   Count_Skills_Rec Count_Skills_Off Rec_to_Off_Ratio           Usability  \
# 0              169              184             0.92  Neutral or Average
# 1               40               42             0.95      Very Satisfied
# 2              118              100             1.18   Very Dissatisfied
# 3               83               68             1.22  Neutral or Average
# 4              142              152             0.93        Dissatisfied
#
#     Speed_Performance Feature_Satisfaction Security_Satisfaction  \
# 0   Very Dissatisfied         Dissatisfied          Dissatisfied
# 1  Neutral or Average         Dissatisfied             Satisfied
# 2           Satisfied    Very Dissatisfied        Very Satisfied
# 3  Neutral or Average   Neutral or Average        Very Satisfied
# 4   Very Dissatisfied    Very Dissatisfied          Dissatisfied
#
#      Customer_Support
# 0        Dissatisfied
# 1   Very Dissatisfied
# 2        Dissatisfied
# 3  Neutral or Average
# 4      Very Satisfied
#
# [5 rows x 97 columns]

# %%
combined_df.to_csv('Skillswap_Data_Raw.csv', index=False)
