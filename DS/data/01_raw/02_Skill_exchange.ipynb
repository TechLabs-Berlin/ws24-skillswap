# %%
import pandas as pd
import random

# %%
# Skill portfolio
# Define offered skill categories as lists
Programming_and_Software_Development_off = []
Project_Management_off = []
Accounting_and_Finance_off = []
Marketing_and_Advertising_off = []
Sales_and_Customer_Service_off = []
Human_Resources_and_Leadership_off = []
Graphic_Design_and_Illustration_off = []
Photography_and_Photo_Editing_off = []
Music_instruments_Composition_and_Production_off = []
Writing_and_Editing_off = []
Arts_and_Crafts_and_DIY_Projects_off = []
Learning_Foreign_Languages_off = []
Written_and_Oral_Communication_in_Various_Languages_off = []
Interpretation_and_Translation_off = []
Computer_and_Software_Application_Operation_off = []
Network_Administration_and_IT_Support_off = []
Electronics_and_Robotics_off = []
Web_Design_and_Development_off = []
Data_Analysis_and_Visualization_off = []
Interpersonal_Communication_off = []
Conflict_Resolution_and_Mediation_off = []
Empathy_and_Emotional_Intelligence_off = []
Leadership_Skills_and_Teamwork_off = []
Networking_and_Relationship_Management_off = []
Cooking_and_Baking_off = []
Gardening_and_Farming_off = []
DIY_and_Repairs_off = []
Driving_and_Vehicle_Maintenance_off = []
First_Aid_and_Life_Saving_Techniques_off = []
Mathematics_and_Sciences_off = []
History_and_Social_Sciences_off = []
Literature_and_Philosophy_off = []
Research_Methods_and_Academic_Writing_off = []
Academic_Reading_and_Critique_off = []
Time_Management_and_Organization_off = []
Stress_Management_and_Mindfulness_off = []
Financial_Planning_and_Budgeting_off = []
Self_Defense_and_Personal_Safety_off = []
Healthcare_and_Nutrition_off = []

# %%
# Define possible skill levels
possible_levels = ["NaN", "Novice", "Beginner", "Intermediate", "Advanced", "Expert"]

# Generate random values for each skill-list
for skill_list in [
    Programming_and_Software_Development_off,
    Project_Management_off,
    Accounting_and_Finance_off,
    Marketing_and_Advertising_off,
    Sales_and_Customer_Service_off,
    Human_Resources_and_Leadership_off,
    Graphic_Design_and_Illustration_off,
    Photography_and_Photo_Editing_off,
    Music_instruments_Composition_and_Production_off,
    Writing_and_Editing_off,
    Arts_and_Crafts_and_DIY_Projects_off,
    Learning_Foreign_Languages_off,
    Written_and_Oral_Communication_in_Various_Languages_off,
    Interpretation_and_Translation_off,
    Computer_and_Software_Application_Operation_off,
    Network_Administration_and_IT_Support_off,
    Electronics_and_Robotics_off,
    Web_Design_and_Development_off,
    Data_Analysis_and_Visualization_off,
    Interpersonal_Communication_off,
    Conflict_Resolution_and_Mediation_off,
    Empathy_and_Emotional_Intelligence_off,
    Leadership_Skills_and_Teamwork_off,
    Networking_and_Relationship_Management_off,
    Cooking_and_Baking_off,
    Gardening_and_Farming_off,
    DIY_and_Repairs_off,
    Driving_and_Vehicle_Maintenance_off,
    First_Aid_and_Life_Saving_Techniques_off,
    Mathematics_and_Sciences_off,
    History_and_Social_Sciences_off,
    Literature_and_Philosophy_off,
    Research_Methods_and_Academic_Writing_off,
    Academic_Reading_and_Critique_off,
    Time_Management_and_Organization_off,
    Stress_Management_and_Mindfulness_off,
    Financial_Planning_and_Budgeting_off,
    Self_Defense_and_Personal_Safety_off,
    Healthcare_and_Nutrition_off
]:
    # Generate random values for the current list
    for _ in range(750):
        skill_list.append(random.choice(possible_levels))

# %%
# Skill interests
# Define demanded skill categories as lists
Programming_and_Software_Development_dem = []
Project_Management_dem = []
Accounting_and_Finance_dem = []
Marketing_and_Advertising_dem = []
Sales_and_Customer_Service_dem = []
Human_Resources_and_Leadership_dem = []
Graphic_Design_and_Illustration_dem = []
Photography_and_Photo_Editing_dem = []
Music_instruments_Composition_and_Production_dem = []
Writing_and_Editing_dem = []
Arts_and_Crafts_and_DIY_Projects_dem = []
Learning_Foreign_Languages_dem = []
Written_and_Oral_Communication_in_Various_Languages_dem = []
Interpretation_and_Translation_dem = []
Computer_and_Software_Application_Operation_dem = []
Network_Administration_and_IT_Support_dem = []
Electronics_and_Robotics_dem = []
Web_Design_and_Development_dem = []
Data_Analysis_and_Visualization_dem = []
Interpersonal_Communication_dem = []
Conflict_Resolution_and_Mediation_dem = []
Empathy_and_Emotional_Intelligence_dem = []
Leadership_Skills_and_Teamwork_dem = []
Networking_and_Relationship_Management_dem = []
Cooking_and_Baking_dem = []
Gardening_and_Farming_dem = []
DIY_and_Repairs_dem = []
Driving_and_Vehicle_Maintenance_dem = []
First_Aid_and_Life_Saving_Techniques_dem = []
Mathematics_and_Sciences_dem = []
History_and_Social_Sciences_dem = []
Literature_and_Philosophy_dem = []
Research_Methods_and_Academic_Writing_dem = []
Academic_Reading_and_Critique_dem = []
Time_Management_and_Organization_dem = []
Stress_Management_and_Mindfulness_dem = []
Financial_Planning_and_Budgeting_dem = []
Self_Defense_and_Personal_Safety_dem = []
Healthcare_and_Nutrition_dem = []

# %%
# Define possible skill levels
possible_levels = ["NaN", "Novice", "Beginner", "Intermediate", "Advanced", "Expert"]

# Generate random values for each skill-list
for skill_list in [
    Programming_and_Software_Development_dem,
    Project_Management_dem,
    Accounting_and_Finance_dem,
    Marketing_and_Advertising_dem,
    Sales_and_Customer_Service_dem,
    Human_Resources_and_Leadership_dem,
    Graphic_Design_and_Illustration_dem,
    Photography_and_Photo_Editing_dem,
    Music_instruments_Composition_and_Production_dem,
    Writing_and_Editing_dem,
    Arts_and_Crafts_and_DIY_Projects_dem,
    Learning_Foreign_Languages_dem,
    Written_and_Oral_Communication_in_Various_Languages_dem,
    Interpretation_and_Translation_dem,
    Computer_and_Software_Application_Operation_dem,
    Network_Administration_and_IT_Support_dem,
    Electronics_and_Robotics_dem,
    Web_Design_and_Development_dem,
    Data_Analysis_and_Visualization_dem,
    Interpersonal_Communication_dem,
    Conflict_Resolution_and_Mediation_dem,
    Empathy_and_Emotional_Intelligence_dem,
    Leadership_Skills_and_Teamwork_dem,
    Networking_and_Relationship_Management_dem,
    Cooking_and_Baking_dem,
    Gardening_and_Farming_dem,
    DIY_and_Repairs_dem,
    Driving_and_Vehicle_Maintenance_dem,
    First_Aid_and_Life_Saving_Techniques_dem,
    Mathematics_and_Sciences_dem,
    History_and_Social_Sciences_dem,
    Literature_and_Philosophy_dem,
    Research_Methods_and_Academic_Writing_dem,
    Academic_Reading_and_Critique_dem,
    Time_Management_and_Organization_dem,
    Stress_Management_and_Mindfulness_dem,
    Financial_Planning_and_Budgeting_dem,
    Self_Defense_and_Personal_Safety_dem,
    Healthcare_and_Nutrition_dem
]:
    # Generate random values for the current list
    for _ in range(750):
        skill_list.append(random.choice(possible_levels))

# %%
skill_table = {
    
    #Skills offered
    "Programming_and_Software_Development_off": Programming_and_Software_Development_off,
    "Project_Management_off": Project_Management_off,
    "Accounting_and_Finance_off": Accounting_and_Finance_off,
    "Marketing_and_Advertising_off": Marketing_and_Advertising_off,
    "Sales_and_Customer_Service_off": Sales_and_Customer_Service_off,
    "Human_Resources_and_Leadership_off": Human_Resources_and_Leadership_off,
    "Graphic_Design_and_Illustration_off": Graphic_Design_and_Illustration_off,
    "Photography_and_Photo_Editing_off": Photography_and_Photo_Editing_off,
    "Music_instruments_Composition_and_Production_off": Music_instruments_Composition_and_Production_off,
    "Writing_and_Editing_off": Writing_and_Editing_off,
    "Arts_and_Crafts_and_DIY_Projects_off": Arts_and_Crafts_and_DIY_Projects_off,
    "Learning_Foreign_Languages_off": Learning_Foreign_Languages_off,
    "Written_and_Oral_Communication_in_Various_Languages_off": Written_and_Oral_Communication_in_Various_Languages_off,
    "Interpretation_and_Translation_off": Interpretation_and_Translation_off,
    "Computer_and_Software_Application_Operation_off": Computer_and_Software_Application_Operation_off,
    "Network_Administration_and_IT_Support_off": Network_Administration_and_IT_Support_off,
    "Electronics_and_Robotics_off": Electronics_and_Robotics_off,
    "Web_Design_and_Development_off": Web_Design_and_Development_off,
    "Data_Analysis_and_Visualization_off": Data_Analysis_and_Visualization_off,
    "Interpersonal_Communication_off": Interpersonal_Communication_off,
    "Conflict_Resolution_and_Mediation_off": Conflict_Resolution_and_Mediation_off,
    "Empathy_and_Emotional_Intelligence_off": Empathy_and_Emotional_Intelligence_off,
    "Leadership_Skills_and_Teamwork_off": Leadership_Skills_and_Teamwork_off,
    "Networking_and_Relationship_Management_off": Networking_and_Relationship_Management_off,
    "Cooking_and_Baking_off": Cooking_and_Baking_off,
    "Gardening_and_Farming_off": Gardening_and_Farming_off,
    "DIY_and_Repairs_off": DIY_and_Repairs_off,
    "Driving_and_Vehicle_Maintenance_off": Driving_and_Vehicle_Maintenance_off,
    "First_Aid_and_Life_Saving_Techniques_off": First_Aid_and_Life_Saving_Techniques_off,
    "Mathematics_and_Sciences_off": Mathematics_and_Sciences_off,
    "History_and_Social_Sciences_off": History_and_Social_Sciences_off,
    "Literature_and_Philosophy_off": Literature_and_Philosophy_off,
    "Research_Methods_and_Academic_Writing_off": Research_Methods_and_Academic_Writing_off,
    "Academic_Reading_and_Critique_off": Academic_Reading_and_Critique_off,
    "Time_Management_and_Organization_off": Time_Management_and_Organization_off,
    "Stress_Management_and_Mindfulness_off": Stress_Management_and_Mindfulness_off,
    "Financial_Planning_and_Budgeting_off": Financial_Planning_and_Budgeting_off,
    "Self_Defense_and_Personal_Safety_off": Self_Defense_and_Personal_Safety_off,
    "Healthcare_and_Nutrition_off": Healthcare_and_Nutrition_off,
   
    # Skill Interests
    'Programming_and_Software_Development_dem': Programming_and_Software_Development_dem,
    'Project_Management_dem': Project_Management_dem,
    'Accounting_and_Finance_dem': Accounting_and_Finance_dem,
    'Marketing_and_Advertising_dem': Marketing_and_Advertising_dem,
    'Sales_and_Customer_Service_dem': Sales_and_Customer_Service_dem,
    'Human_Resources_and_Leadership_dem': Human_Resources_and_Leadership_dem,
    'Graphic_Design_and_Illustration_dem': Graphic_Design_and_Illustration_dem,
    'Photography_and_Photo_Editing_dem': Photography_and_Photo_Editing_dem,
    'Music_instruments_Composition_and_Production_dem': Music_instruments_Composition_and_Production_dem,
    'Writing_and_Editing_dem': Writing_and_Editing_dem,
    'Arts_and_Crafts_and_DIY_Projects_dem': Arts_and_Crafts_and_DIY_Projects_dem,
    'Learning_Foreign_Languages_dem': Learning_Foreign_Languages_dem,
    'Written_and_Oral_Communication_in_Various_Languages_dem': Written_and_Oral_Communication_in_Various_Languages_dem,
    'Interpretation_and_Translation_dem': Interpretation_and_Translation_dem,
    'Computer_and_Software_Application_Operation_dem': Computer_and_Software_Application_Operation_dem,
    'Network_Administration_and_IT_Support_dem': Network_Administration_and_IT_Support_dem,
    'Electronics_and_Robotics_dem': Electronics_and_Robotics_dem,
    'Web_Design_and_Development_dem': Web_Design_and_Development_dem,
    'Data_Analysis_and_Visualization_dem': Data_Analysis_and_Visualization_dem,
    'Interpersonal_Communication_dem': Interpersonal_Communication_dem,
    'Conflict_Resolution_and_Mediation_dem': Conflict_Resolution_and_Mediation_dem,
    'Empathy_and_Emotional_Intelligence_dem': Empathy_and_Emotional_Intelligence_dem,
    'Leadership_Skills_and_Teamwork_dem': Leadership_Skills_and_Teamwork_dem,
    'Networking_and_Relationship_Management_dem': Networking_and_Relationship_Management_dem,
    'Cooking_and_Baking_dem': Cooking_and_Baking_dem,
    'Gardening_and_Farming_dem': Gardening_and_Farming_dem,
    'DIY_and_Repairs_dem': DIY_and_Repairs_dem,
    'Driving_and_Vehicle_Maintenance_dem': Driving_and_Vehicle_Maintenance_dem,
    'First_Aid_and_Life_Saving_Techniques_dem': First_Aid_and_Life_Saving_Techniques_dem,
    'Mathematics_and_Sciences_dem': Mathematics_and_Sciences_dem,
    'History_and_Social_Sciences_dem': History_and_Social_Sciences_dem,
    'Literature_and_Philosophy_dem': Literature_and_Philosophy_dem,
    'Research_Methods_and_Academic_Writing_dem': Research_Methods_and_Academic_Writing_dem,
    'Academic_Reading_and_Critique_dem': Academic_Reading_and_Critique_dem,
    'Time_Management_and_Organization_dem': Time_Management_and_Organization_dem,
    'Stress_Management_and_Mindfulness_dem': Stress_Management_and_Mindfulness_dem,
    'Financial_Planning_and_Budgeting_dem': Financial_Planning_and_Budgeting_dem,
    'Self_Defense_and_Personal_Safety_dem': Self_Defense_and_Personal_Safety_dem,
    'Healthcare_and_Nutrition_dem': Healthcare_and_Nutrition_dem
}

Skill_exchange = pd.DataFrame(skill_table)

Skill_exchange.head()
# Out:
#   Programming_and_Software_Development_off Project_Management_off  \
# 0                                 Advanced                 Expert
# 1                                      NaN                    NaN
# 2                                 Beginner                    NaN
# 3                                   Novice           Intermediate
# 4                             Intermediate           Intermediate
#
#   Accounting_and_Finance_off Marketing_and_Advertising_off  \
# 0               Intermediate                        Expert
# 1               Intermediate                           NaN
# 2               Intermediate                  Intermediate
# 3                   Beginner                           NaN
# 4               Intermediate                  Intermediate
#
#   Sales_and_Customer_Service_off Human_Resources_and_Leadership_off  \
# 0                         Expert                             Novice
# 1                   Intermediate                             Novice
# ...

# %%
Skill_exchange.to_csv('Skill_exchange.csv', index=False)

# %%
# Create Overview over dtypes
column_info = []

for column, dtype in Skill_exchange.dtypes.items():
    column_info.append((column, str(dtype)))
    
df_column_info = pd.DataFrame(column_info, columns=['User Data', 'Data Type'])
df_column_info['Factor'] = 'Skill_Exchange'
factor_column = df_column_info.pop('Factor')

# Insert the "Factor" column as the first column
df_column_info.insert(0, 'Factor', factor_column)
df_column_info.head()
# Out:
#            Factor                                 User Data Data Type
# 0  Skill_Exchange  Programming_and_Software_Development_off    object
# 1  Skill_Exchange                    Project_Management_off    object
# 2  Skill_Exchange                Accounting_and_Finance_off    object
# 3  Skill_Exchange             Marketing_and_Advertising_off    object
# 4  Skill_Exchange            Sales_and_Customer_Service_off    object

# %%
# df_column_info.to_csv('dtype_Skill_Exchange.csv', index=False)
