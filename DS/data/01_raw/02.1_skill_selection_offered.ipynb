# %%
import random
import pandas as pd
import numpy as np

# %%
# Define the skill domains
# Pick a random number between 1 and 3
# Select random skill domains
# Create a list to store the samples
# Generate 750 random skill domain samples


skill_domains = [
    "Professional_Skills",
    "Creative_Skills",
    "Language_Skills",
    "Technical_Skills",
    "Social_Skills",
    "Practical_Skills",
    "Academic_Skills",
    "Life_Skills"
]

def select_random_skills():
    num_skills = random.randint(1, 3)
    selected_skills = random.sample(skill_domains, num_skills)
    return selected_skills

random_skill_samples = []

for _ in range(750):
    random_skills = select_random_skills()
    random_skill_samples.append(random_skills)
    
print(random_skill_samples)
# Out:
# [['Life_Skills', 'Language_Skills'], ['Technical_Skills', 'Life_Skills', 'Practical_Skills'], ['Professional_Skills', 'Social_Skills'], ['Practical_Skills'], ['Life_Skills', 'Technical_Skills', 'Social_Skills'], ['Life_Skills'], ['Academic_Skills'], ['Professional_Skills', 'Language_Skills', 'Technical_Skills'], ['Language_Skills', 'Practical_Skills', 'Professional_Skills'], ['Professional_Skills', 'Creative_Skills', 'Language_Skills'], ['Social_Skills', 'Professional_Skills'], ['Social_Skills'], ['Creative_Skills', 'Social_Skills'], ['Social_Skills'], ['Language_Skills', 'Technical_Skills'], ['Technical_Skills', 'Academic_Skills', 'Practical_Skills'], ['Academic_Skills'], ['Technical_Skills'], ['Technical_Skills', 'Academic_Skills', 'Professional_Skills'], ['Technical_Skills'], ['Creative_Skills'], ['Language_Skills', 'Academic_Skills'], ['Practical_Skills'], ['Life_Skills', 'Social_Skills'], ['Life_Skills', 'Language_Skills', 'Practical_Skills'], ['Professional_Skills', 'Life_Skills'], ['Professional_Skills', 'Social_Skills', 'Language_Skills'], ['Creative_Skills', 'Practical_Skills', 'Life_Skills'], ['Technical_Skills', 'Professional_Skills'], ['Creative_Skills'], ['Professional_Skills', 'Academic_Skills', 'Language_Skills'], ['Creative_Skills', 'Life_Skills'], ['Social_Skills'], ['Life_Skills'], ['Life_Skills', 'Practical_Skills', 'Creative_Skills'], ['Technical_Skills', 'Practical_Skills', 'Life_Skills'], ['Practical_Skills', 'Professional_Skills', 'Technical_Skills'], ['Social_Skills', 'Practical_Skills'], ['Life_Skills'], ['Practical_Skills', 'Technical_Skills', 'Professional_Skills'], ['Language_Skills'], ['Technical_Skills', 'Language_Skills', 'Creative_Skills'], ['Practical_Skills', 'Language_Skills'], ['Language_Skills', 'Practical_Skills'], ['Professional_Skills', 'Social_Skills'], ['Language_Skills', 'Social_Skills', 'Creative_Skills'], ['Life_Skills'], ['Social_Skills'], ['Social_Skills', 'Life_Skills'], ['Professional_Skills', 'Creative_Skills', 'Language_Skills'], ['Professional_Skills'], ['Life_Skills', 'Academic_Skills'], ['Professional_Skills', 'Life_Skills'], ['Technical_Skills'], ['Language_Skills', 'Academic_Skills'], ['Creative_Skills'], ['Social_Skills'], ['Social_Skills', 'Professional_Skills'], ['Professional_Skills', 'Creative_Skills', 'Academic_Skills'], ['Practical_Skills'], ['Life_Skills'], ['Academic_Skills'], ['Professional_Skills'], ['Social_Skills'], ['Academic_Skills', 'Language_Skills'], ['Technical_Skills', 'Creative_Skills', 'Life_Skills'], ['Creative_Skills', 'Practical_Skills', 'Life_Skills'], ['Language_Skills', 'Professional_Skills'], ['Social_Skills', 'Language_Skills'], ['Creative_Skills', 'Academic_Skills'], ['Life_Skills', 'Technical_Skills'], ['Social_Skills', 'Life_Skills', 'Practical_Skills'], ['Academic_Skills'], ['Creative_Skills'], ['Social_Skills', 'Language_Skills'], ['Technical_Skills', 'Academic_Skills', 'Practical_Skills'], ['Life_Skills', 'Creative_Skills'], ['Professional_Skills'], ['Creative_Skills', 'Language_Skills', 'Life_Skills'], ['Practical_Skills', 'Life_Skills'], ['Creative_Skills'], ['Technical_Skills'], ['Practical_Skills', 'Social_Skills'], ['Practical_Skills', 'Creative_Skills'], ['Creative_Skills'], ['Professional_Skills'], ['Professional_Skills', 'Creative_Skills', 'Life_Skills'], ['Social_Skills', 'Language_Skills', 'Practical_Skills'], ['Social_Skills', 'Professional_Skills'], ['Language_Skills'], ['Practical_Skills'], ['Technical_Skills', 'Academic_Skills', 'Professional_Skills'], ['Language_Skills', 'Social_Skills', 'Professional_Skills'], ['Creative_Skills', 'Life_Skills', 'Academic_Skills'], ['Language_Skills', 'Academic_Skills'], ['Academic_Skills'], ['Professional_Skills'], ['Language_Skills', 'Professional_Skills'], ['Practical_Skills', 'Creative_Skills', 'Professional_Skills'], ['Technical_Skills', 'Creative_Skills', 'Practical_Skills'], ['Technical_Skills'], ['Academic_Skills'], ['Life_Skills', 'Professional_Skills'], ['Language_Skills'], ['Ac ...

# %%
# Skill domains and respective skills
skills_dict = {
    'Professional_Skills': [
        'Programming_and_Software_Development_off',
        'Project_Management_off',
        'Accounting_and_Finance_off',
        'Marketing_and_Advertising_off',
        'Sales_and_Customer_Service_off',
        'Human_Resources_and_Leadership_off'
    ],
    'Creative_Skills': [
        'Graphic_Design_and_Illustration_off',
        'Photography_and_Photo_Editing_off',
        'Music_instruments_Composition_and_Production_off',
        'Writing_and_Editing_off',
        'Arts_and_Crafts_and_DIY_Projects_off'
    ],
    'Language_Skills': [
        'Learning_Foreign_Languages_off',
        'Written_and_Oral_Communication_in_Various_Languages_off',
        'Interpretation_and_Translation_off'
    ],
    'Technical_Skills': [
        'Computer_and_Software_Application_Operation_off',
        'Network_Administration_and_IT_Support_off',
        'Electronics_and_Robotics_off',
        'Web_Design_and_Development_off',
        'Data_Analysis_and_Visualization_off'
    ],
    'Social_Skills': [
        'Interpersonal_Communication_off',
        'Conflict_Resolution_and_Mediation_off',
        'Empathy_and_Emotional_Intelligence_off',
        'Leadership_Skills_and_Teamwork_off',
        'Networking_and_Relationship_Management_off'
    ],
    'Practical_Skills': [
        'Cooking_and_Baking_off',
        'Gardening_and_Farming_off',
        'DIY_and_Repairs_off',
        'Driving_and_Vehicle_Maintenance_off',
        'First_Aid_and_Life_Saving_Techniques_off'
    ],
    'Academic_Skills': [
        'Mathematics_and_Sciences_off',
        'History_and_Social_Sciences_off',
        'Literature_and_Philosophy_off',
        'Research_Methods_and_Academic_Writing_off',
        'Academic_Reading_and_Critique_off'
    ],
    'Life_Skills': [
        'Time_Management_and_Organization_off',
        'Stress_Management_and_Mindfulness_off',
        'Financial_Planning_and_Budgeting_off',
        'Self_Defense_and_Personal_Safety_off',
        'Healthcare_and_Nutrition_off'
    ]
}

# %%
# Initialize a list to store the matched skills for each domain sample
# Iterate through each domain sample in random_skill_samples
# Initialize an empty list to store the matched skills for the current sample
# Iterate through each skill domain in the current sample
# Retrieve the matching skills from skills_dict and extend the matched_skills list
# Append the matched skills for the current sample to the matched_skills_samples list

matched_skills_samples = []

for sample in random_skill_samples:
    matched_skills = []
    for skill_domain in sample:
        matched_skills.extend(skills_dict.get(skill_domain, []))
    matched_skills_samples.append(matched_skills)
    
    
print(matched_skills_samples)
# Out:
# [['Time_Management_and_Organization_off', 'Stress_Management_and_Mindfulness_off', 'Financial_Planning_and_Budgeting_off', 'Self_Defense_and_Personal_Safety_off', 'Healthcare_and_Nutrition_off', 'Learning_Foreign_Languages_off', 'Written_and_Oral_Communication_in_Various_Languages_off', 'Interpretation_and_Translation_off'], ['Computer_and_Software_Application_Operation_off', 'Network_Administration_and_IT_Support_off', 'Electronics_and_Robotics_off', 'Web_Design_and_Development_off', 'Data_Analysis_and_Visualization_off', 'Time_Management_and_Organization_off', 'Stress_Management_and_Mindfulness_off', 'Financial_Planning_and_Budgeting_off', 'Self_Defense_and_Personal_Safety_off', 'Healthcare_and_Nutrition_off', 'Cooking_and_Baking_off', 'Gardening_and_Farming_off', 'DIY_and_Repairs_off', 'Driving_and_Vehicle_Maintenance_off', 'First_Aid_and_Life_Saving_Techniques_off'], ['Programming_and_Software_Development_off', 'Project_Management_off', 'Accounting_and_Finance_off', 'Marketing_and_Advertising_off', 'Sales_and_Customer_Service_off', 'Human_Resources_and_Leadership_off', 'Interpersonal_Communication_off', 'Conflict_Resolution_and_Mediation_off', 'Empathy_and_Emotional_Intelligence_off', 'Leadership_Skills_and_Teamwork_off', 'Networking_and_Relationship_Management_off'], ['Cooking_and_Baking_off', 'Gardening_and_Farming_off', 'DIY_and_Repairs_off', 'Driving_and_Vehicle_Maintenance_off', 'First_Aid_and_Life_Saving_Techniques_off'], ['Time_Management_and_Organization_off', 'Stress_Management_and_Mindfulness_off', 'Financial_Planning_and_Budgeting_off', 'Self_Defense_and_Personal_Safety_off', 'Healthcare_and_Nutrition_off', 'Computer_and_Software_Application_Operation_off', 'Network_Administration_and_IT_Support_off', 'Electronics_and_Robotics_off', 'Web_Design_and_Development_off', 'Data_Analysis_and_Visualization_off', 'Interpersonal_Communication_off', 'Conflict_Resolution_and_Mediation_off', 'Empathy_and_Emotional_Intelligence_off', 'Leadership_Skills_and_Teamwork_off', 'Networking_and_Relationship_Management_off'], ['Time_Management_and_Organization_off', 'Stress_Management_and_Mindfulness_off', 'Financial_Planning_and_Budgeting_off', 'Self_Defense_and_Personal_Safety_off', 'Healthcare_and_Nutrition_off'], ['Mathematics_and_Sciences_off', 'History_and_Social_Sciences_off', 'Literature_and_Philosophy_off', 'Research_Methods_and_Academic_Writing_off', 'Academic_Reading_and_Critique_off'], ['Programming_and_Software_Development_off', 'Project_Management_off', 'Accounting_and_Finance_off', 'Marketing_and_Advertising_off', 'Sales_and_Customer_Service_off', 'Human_Resources_and_Leadership_off', 'Learning_Foreign_Languages_off', 'Written_and_Oral_Communication_in_Various_Languages_off', 'Interpretation_and_Translation_off', 'Computer_and_Software_Application_Operation_off', 'Network_Administration_and_IT_Support_off', 'Electronics_and_Robotics_off', 'Web_Design_and_Development_off', 'Data_Analysis_and_Visualization_off'], ['Learning_Foreign_Languages_off', 'Written_and_Oral_Communication_in_Various_Languages_off', 'Interpretation_and_Translation_off', 'Cooking_and_Baking_off', 'Gardening_and_Farming_off', 'DIY_and_Repairs_off', 'Driving_and_Vehicle_Maintenance_off', 'First_Aid_and_Life_Saving_Techniques_off', 'Programming_and_Software_Development_off', 'Project_Management_off', 'Accounting_and_Finance_off', 'Marketing_and_Advertising_off', 'Sales_and_Customer_Service_off', 'Human_Resources_and_Leadership_off'], ['Programming_and_Software_Development_off', 'Project_Management_off', 'Accounting_and_Finance_off', 'Marketing_and_Advertising_off', 'Sales_and_Customer_Service_off', 'Human_Resources_and_Leadership_off', 'Graphic_Design_and_Illustration_off', 'Photography_and_Photo_Editing_off', 'Music_instruments_Composition_and_Production_off', 'Writing_and_Editing_off', 'Arts_and_Crafts_and_DIY_Projects_off', 'Learning_Foreign_Languages_off', 'Written_and_Oral_Communication_in_Various_Languages_off', 'Interpretation_and_Translation_off ...

# %%
Matched_skills_df = pd.DataFrame({"Matched_skills_samples": matched_skills_samples})
Matched_skills_df
# Out:
#                                 Matched_skills_samples
# 0    [Time_Management_and_Organization_off, Stress_...
# 1    [Computer_and_Software_Application_Operation_o...
# 2    [Programming_and_Software_Development_off, Pro...
# 3    [Cooking_and_Baking_off, Gardening_and_Farming...
# 4    [Time_Management_and_Organization_off, Stress_...
# ..                                                 ...
# 745  [Learning_Foreign_Languages_off, Written_and_O...
# 746  [Programming_and_Software_Development_off, Pro...
# 747  [Time_Management_and_Organization_off, Stress_...
# 748  [Computer_and_Software_Application_Operation_o...
# 749  [Programming_and_Software_Development_off, Pro...
#
# [750 rows x 1 columns]

# %%
# Goal: Select a random expert skill
# Initialize a list to store the randomly selected skills
# Iterate over each row in the DataFrame
# Extract the list of matched skills from the current row
# Check if the list of matched skills is not empty
# Select a random skill from the list
# Append the randomly selected skill to the new list
# If the list of matched skills is empty, append None or any placeholder value

expert_skill = []

for index, row in Matched_skills_df.iterrows():
    matched_skills = row['Matched_skills_samples']
    
    if matched_skills:
        random_skill = random.choice(matched_skills)
        expert_skill.append(random_skill)
    else:
        expert_skill.append(None)

# %%
Expert_df = pd.DataFrame({"Expert_skill": expert_skill})
Expert_df
# Out:
#                               Expert_skill
# 0             Healthcare_and_Nutrition_off
# 1             Electronics_and_Robotics_off
# 2            Marketing_and_Advertising_off
# 3                   Cooking_and_Baking_off
# 4       Leadership_Skills_and_Teamwork_off
# ..                                     ...
# 745          Literature_and_Philosophy_off
# 746         Sales_and_Customer_Service_off
# 747  Stress_Management_and_Mindfulness_off
# 748          Literature_and_Philosophy_off
# 749             Accounting_and_Finance_off
#
# [750 rows x 1 columns]

# %%
# Define the columns of the final data frame to then fill them with input 
# Skill portfolio
# Define offered skill categories as lists
Programming_and_Software_Development_off = []
Project_Management_off = []
Accounting_and_Finance_off = []
Marketing_and_Advertising_off = []
Sales_and_Customer_Service_off = []
Human_Resources_and_Leadership_off = []
Graphic_Design_and_Illustration_off = []
Photography_and_Photo_Editing_off = []
Music_instruments_Composition_and_Production_off = []
Writing_and_Editing_off = []
Arts_and_Crafts_and_DIY_Projects_off = []
Learning_Foreign_Languages_off = []
Written_and_Oral_Communication_in_Various_Languages_off = []
Interpretation_and_Translation_off = []
Computer_and_Software_Application_Operation_off = []
Network_Administration_and_IT_Support_off = []
Electronics_and_Robotics_off = []
Web_Design_and_Development_off = []
Data_Analysis_and_Visualization_off = []
Interpersonal_Communication_off = []
Conflict_Resolution_and_Mediation_off = []
Empathy_and_Emotional_Intelligence_off = []
Leadership_Skills_and_Teamwork_off = []
Networking_and_Relationship_Management_off = []
Cooking_and_Baking_off = []
Gardening_and_Farming_off = []
DIY_and_Repairs_off = []
Driving_and_Vehicle_Maintenance_off = []
First_Aid_and_Life_Saving_Techniques_off = []
Mathematics_and_Sciences_off = []
History_and_Social_Sciences_off = []
Literature_and_Philosophy_off = []
Research_Methods_and_Academic_Writing_off = []
Academic_Reading_and_Critique_off = []
Time_Management_and_Organization_off = []
Stress_Management_and_Mindfulness_off = []
Financial_Planning_and_Budgeting_off = []
Self_Defense_and_Personal_Safety_off = []
Healthcare_and_Nutrition_off = []

# %%
skill_table = {
    
    #Skills offered
    "Programming_and_Software_Development_off": Programming_and_Software_Development_off,
    "Project_Management_off": Project_Management_off,
    "Accounting_and_Finance_off": Accounting_and_Finance_off,
    "Marketing_and_Advertising_off": Marketing_and_Advertising_off,
    "Sales_and_Customer_Service_off": Sales_and_Customer_Service_off,
    "Human_Resources_and_Leadership_off": Human_Resources_and_Leadership_off,
    "Graphic_Design_and_Illustration_off": Graphic_Design_and_Illustration_off,
    "Photography_and_Photo_Editing_off": Photography_and_Photo_Editing_off,
    "Music_instruments_Composition_and_Production_off": Music_instruments_Composition_and_Production_off,
    "Writing_and_Editing_off": Writing_and_Editing_off,
    "Arts_and_Crafts_and_DIY_Projects_off": Arts_and_Crafts_and_DIY_Projects_off,
    "Learning_Foreign_Languages_off": Learning_Foreign_Languages_off,
    "Written_and_Oral_Communication_in_Various_Languages_off": Written_and_Oral_Communication_in_Various_Languages_off,
    "Interpretation_and_Translation_off": Interpretation_and_Translation_off,
    "Computer_and_Software_Application_Operation_off": Computer_and_Software_Application_Operation_off,
    "Network_Administration_and_IT_Support_off": Network_Administration_and_IT_Support_off,
    "Electronics_and_Robotics_off": Electronics_and_Robotics_off,
    "Web_Design_and_Development_off": Web_Design_and_Development_off,
    "Data_Analysis_and_Visualization_off": Data_Analysis_and_Visualization_off,
    "Interpersonal_Communication_off": Interpersonal_Communication_off,
    "Conflict_Resolution_and_Mediation_off": Conflict_Resolution_and_Mediation_off,
    "Empathy_and_Emotional_Intelligence_off": Empathy_and_Emotional_Intelligence_off,
    "Leadership_Skills_and_Teamwork_off": Leadership_Skills_and_Teamwork_off,
    "Networking_and_Relationship_Management_off": Networking_and_Relationship_Management_off,
    "Cooking_and_Baking_off": Cooking_and_Baking_off,
    "Gardening_and_Farming_off": Gardening_and_Farming_off,
    "DIY_and_Repairs_off": DIY_and_Repairs_off,
    "Driving_and_Vehicle_Maintenance_off": Driving_and_Vehicle_Maintenance_off,
    "First_Aid_and_Life_Saving_Techniques_off": First_Aid_and_Life_Saving_Techniques_off,
    "Mathematics_and_Sciences_off": Mathematics_and_Sciences_off,
    "History_and_Social_Sciences_off": History_and_Social_Sciences_off,
    "Literature_and_Philosophy_off": Literature_and_Philosophy_off,
    "Research_Methods_and_Academic_Writing_off": Research_Methods_and_Academic_Writing_off,
    "Academic_Reading_and_Critique_off": Academic_Reading_and_Critique_off,
    "Time_Management_and_Organization_off": Time_Management_and_Organization_off,
    "Stress_Management_and_Mindfulness_off": Stress_Management_and_Mindfulness_off,
    "Financial_Planning_and_Budgeting_off": Financial_Planning_and_Budgeting_off,
    "Self_Defense_and_Personal_Safety_off": Self_Defense_and_Personal_Safety_off,
    "Healthcare_and_Nutrition_off": Healthcare_and_Nutrition_off,
}

Skills_Offered = pd.DataFrame(skill_table)

Skills_Offered.head()
# Out:
# Empty DataFrame
# Columns: [Programming_and_Software_Development_off, Project_Management_off, Accounting_and_Finance_off, Marketing_and_Advertising_off, Sales_and_Customer_Service_off, Human_Resources_and_Leadership_off, Graphic_Design_and_Illustration_off, Photography_and_Photo_Editing_off, Music_instruments_Composition_and_Production_off, Writing_and_Editing_off, Arts_and_Crafts_and_DIY_Projects_off, Learning_Foreign_Languages_off, Written_and_Oral_Communication_in_Various_Languages_off, Interpretation_and_Translation_off, Computer_and_Software_Application_Operation_off, Network_Administration_and_IT_Support_off, Electronics_and_Robotics_off, Web_Design_and_Development_off, Data_Analysis_and_Visualization_off, Interpersonal_Communication_off, Conflict_Resolution_and_Mediation_off, Empathy_and_Emotional_Intelligence_off, Leadership_Skills_and_Teamwork_off, Networking_and_Relationship_Management_off, Cooking_and_Baking_off, Gardening_and_Farming_off, DIY_and_Repairs_off, Driving_and_Vehicle_Maintenance_off, First_Aid_and_Life_Saving_Techniques_off, Mathematics_and_Sciences_off, History_and_Social_Sciences_off, Literature_and_Philosophy_off, Research_Methods_and_Academic_Writing_off, Academic_Reading_and_Critique_off, Time_Management_and_Organization_off, Stress_Management_and_Mindfulness_off, Financial_Planning_and_Budgeting_off, Self_Defense_and_Personal_Safety_off, Healthcare_and_Nutrition_off]
# Index: []
#
# [0 rows x 39 columns]

# %%
concatenated_df = pd.concat([Skills_Offered, Expert_df, Matched_skills_df], axis=1)
concatenated_df
# Out:
#      Programming_and_Software_Development_off  Project_Management_off  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
# ..                                        ...                     ...
# 745                                       NaN                     NaN
# 746                                       NaN                     NaN
# 747                                       NaN                     NaN
# 748                                       NaN                     NaN
# 749                                       NaN                     NaN
#
#      Accounting_and_Finance_off  Marketing_and_Advertising_off  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# ..                          ...                            ...
# 745                         NaN                            NaN
# 746                         NaN                            NaN
# 747                         NaN                            NaN
# 748                         NaN                            NaN
# 749                         NaN                            NaN
#
#      Sales_and_Customer_Service_off  Human_Resources_and_Leadership_off  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# ..                              ...                                 ...
# 745                             NaN                                 NaN
# 746                             NaN                                 NaN
# 747                             NaN                                 NaN
# 748                             NaN                                 NaN
# 749                             NaN                                 NaN
#
#      Graphic_Design_and_Illustration_off  Photography_and_Photo_Editing_off  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ..                                   ...                                ...
# 745                                  NaN                                NaN
# 746                                  NaN                                NaN
# 747                                  NaN                                NaN
# 748                                  NaN                                NaN
# 749                                  NaN                                NaN
#
#      Music_instruments_Composition_and_Production_off  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 745                                               NaN
# 746                                               NaN
# 747                                               NaN
# 748                                               NaN
# 749                                               NaN
#
#      Writing_and_Editing_off  ...  Literature_and_Philosophy_off  \
# 0                        NaN  ...                            NaN
# 1                        NaN  ...                            NaN
# 2                        NaN  ...                            NaN
# 3                        NaN  ...                            NaN
# 4                        NaN  ...                            NaN
# ..                       ...  ...                            ...
# 745                      NaN  ...                            NaN
# 746                      NaN  ...                            NaN
# 747                      NaN  ...                            NaN
# 748                      NaN  ...                            NaN
# 749                      NaN  ...                            NaN
#
#      Research_Methods_and_Academic_Writing_off  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 745                                        NaN
# 746                                        NaN
# 747                                        NaN
# 748                                        NaN
# 749                                        NaN
#
#      Academic_Reading_and_Critique_off  Time_Management_and_Organization_off  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# ..                                 ...                                   ...
# 745                                NaN                                   NaN
# 746                                NaN                                   NaN
# 747                                NaN                                   NaN
# 748                                NaN                                   NaN
# 749                                NaN                                   NaN
#
#      Stress_Management_and_Mindfulness_off  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 745                                    NaN
# 746                                    NaN
# 747                                    NaN
# 748                                    NaN
# 749                                    NaN
#
#      Financial_Planning_and_Budgeting_off  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 745                                   NaN
# 746                                   NaN
# 747                                   NaN
# 748                                   NaN
# 749                                   NaN
#
#      Self_Defense_and_Personal_Safety_off  Healthcare_and_Nutrition_off  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
# ..                                    ...                           ...
# 745                                   NaN                           NaN
# 746                                   NaN                           NaN
# 747                                   NaN                           NaN
# 748                                   NaN                           NaN
# 749                                   NaN                           NaN
#
#                               Expert_skill  \
# 0             Healthcare_and_Nutrition_off
# 1             Electronics_and_Robotics_off
# 2            Marketing_and_Advertising_off
# 3                   Cooking_and_Baking_off
# 4       Leadership_Skills_and_Teamwork_off
# ..                                     ...
# 745          Literature_and_Philosophy_off
# 746         Sales_and_Customer_Service_off
# 747  Stress_Management_and_Mindfulness_off
# 748          Literature_and_Philosophy_off
# 749             Accounting_and_Finance_off
#
#                                 Matched_skills_samples
# 0    [Time_Management_and_Organization_off, Stress_...
# 1    [Computer_and_Software_Application_Operation_o...
# 2    [Programming_and_Software_Development_off, Pro...
# 3    [Cooking_and_Baking_off, Gardening_and_Farming...
# 4    [Time_Management_and_Organization_off, Stress_...
# ..                                                 ...
# 745  [Learning_Foreign_Languages_off, Written_and_O...
# 746  [Programming_and_Software_Development_off, Pro...
# 747  [Time_Management_and_Organization_off, Stress_...
# 748  [Computer_and_Software_Application_Operation_o...
# 749  [Programming_and_Software_Development_off, Pro...
#
# [750 rows x 41 columns]

# %%
# Make sure that a person is an expert in one skill 
# Extract the value in the "expert_skill" column for the current row
# Iterate over each column in the DataFrame
# Check if the column name matches the expert skill
# Assign "Expert" to the corresponding cell in the matched column

for index, row in concatenated_df.iterrows():
    expert_skill = row['Expert_skill']
    
    for column in concatenated_df.columns:
        if column == expert_skill:
            concatenated_df.at[index, column] = "Expert"
# Out:
# C:\Users\Johannes\AppData\Local\Temp\ipykernel_14540\1063439066.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Expert' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   concatenated_df.at[index, column] = "Expert"

# %%
# Remove the expert skill from the Matched Skills column to make sure the skill level is not overwritten in the next step
# Iterate over each row in the DataFrame
# Extract the value in the "Expert_Level" column for the current row
# Extract the list of matched skills from the "Matched_skills_samples" column
# Check if the value in the "Expert_Level" column is not null
# Remove the value in "Expert_Level" from the list of matched skills, if it exists
# Update the "Matched_skills_samples" column with the modified list of matched skills


for index, row in concatenated_df.iterrows():
    expert_level = row['Expert_skill']
    
    matched_skills = row['Matched_skills_samples']
    
    if pd.notnull(expert_level):
        if expert_level in matched_skills:
            matched_skills.remove(expert_level)
    
    concatenated_df.at[index, 'Matched_skills_samples'] = matched_skills

# %%
concatenated_df
# Out:
#     Programming_and_Software_Development_off Project_Management_off  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
# ..                                       ...                    ...
# 745                                      NaN                    NaN
# 746                                      NaN                    NaN
# 747                                      NaN                    NaN
# 748                                      NaN                    NaN
# 749                                      NaN                    NaN
#
#     Accounting_and_Finance_off Marketing_and_Advertising_off  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                        Expert
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ..                         ...                           ...
# 745                        NaN                           NaN
# 746                        NaN                           NaN
# 747                        NaN                           NaN
# 748                        NaN                           NaN
# 749                     Expert                           NaN
#
#     Sales_and_Customer_Service_off Human_Resources_and_Leadership_off  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ..                             ...                                ...
# 745                            NaN                                NaN
# 746                         Expert                                NaN
# 747                            NaN                                NaN
# 748                            NaN                                NaN
# 749                            NaN                                NaN
#
#     Graphic_Design_and_Illustration_off Photography_and_Photo_Editing_off  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ..                                  ...                               ...
# 745                                 NaN                               NaN
# 746                                 NaN                               NaN
# 747                                 NaN                               NaN
# 748                                 NaN                               NaN
# 749                                 NaN                               NaN
#
#     Music_instruments_Composition_and_Production_off Writing_and_Editing_off  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
# ..                                               ...                     ...
# 745                                              NaN                     NaN
# 746                                              NaN                     NaN
# 747                                              NaN                     NaN
# 748                                              NaN                     NaN
# 749                                              NaN                     NaN
#
#      ... Literature_and_Philosophy_off  \
# 0    ...                           NaN
# 1    ...                           NaN
# 2    ...                           NaN
# 3    ...                           NaN
# 4    ...                           NaN
# ..   ...                           ...
# 745  ...                        Expert
# 746  ...                           NaN
# 747  ...                           NaN
# 748  ...                        Expert
# 749  ...                           NaN
#
#     Research_Methods_and_Academic_Writing_off  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 745                                       NaN
# 746                                       NaN
# 747                                       NaN
# 748                                       NaN
# 749                                       NaN
#
#     Academic_Reading_and_Critique_off Time_Management_and_Organization_off  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ..                                ...                                  ...
# 745                               NaN                                  NaN
# 746                               NaN                                  NaN
# 747                               NaN                                  NaN
# 748                               NaN                                  NaN
# 749                               NaN                                  NaN
#
#     Stress_Management_and_Mindfulness_off  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 745                                   NaN
# 746                                   NaN
# 747                                Expert
# 748                                   NaN
# 749                                   NaN
#
#     Financial_Planning_and_Budgeting_off Self_Defense_and_Personal_Safety_off  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ..                                   ...                                  ...
# 745                                  NaN                                  NaN
# 746                                  NaN                                  NaN
# 747                                  NaN                                  NaN
# 748                                  NaN                                  NaN
# 749                                  NaN                                  NaN
#
#     Healthcare_and_Nutrition_off                           Expert_skill  \
# 0                         Expert           Healthcare_and_Nutrition_off
# 1                            NaN           Electronics_and_Robotics_off
# 2                            NaN          Marketing_and_Advertising_off
# 3                            NaN                 Cooking_and_Baking_off
# 4                            NaN     Leadership_Skills_and_Teamwork_off
# ..                           ...                                    ...
# 745                          NaN          Literature_and_Philosophy_off
# 746                          NaN         Sales_and_Customer_Service_off
# 747                          NaN  Stress_Management_and_Mindfulness_off
# 748                          NaN          Literature_and_Philosophy_off
# 749                          NaN             Accounting_and_Finance_off
#
#                                 Matched_skills_samples
# 0    [Time_Management_and_Organization_off, Stress_...
# 1    [Computer_and_Software_Application_Operation_o...
# 2    [Programming_and_Software_Development_off, Pro...
# 3    [Gardening_and_Farming_off, DIY_and_Repairs_of...
# 4    [Time_Management_and_Organization_off, Stress_...
# ..                                                 ...
# 745  [Learning_Foreign_Languages_off, Written_and_O...
# 746  [Programming_and_Software_Development_off, Pro...
# 747  [Time_Management_and_Organization_off, Financi...
# 748  [Computer_and_Software_Application_Operation_o...
# 749  [Programming_and_Software_Development_off, Pro...
#
# [750 rows x 41 columns]

# %%
# Randomly select a value from possible_levels with a normal distribution to 
# fill the columns (where a person has a skill) with skill levels
# Define possible skill levels
# Assumption: Usually people are beginners in the fields where they are not Experts (That's why they are on the platform)
# Iterate over each row in the DataFrame
# Extract the list of matched skills from the current row
# Iterate over each column in the DataFrame
# Check if the column name matches any of the skills in matched_skills
# Define parameters for the normal distribution
# Generate random index from a normal distribution
# Ensure the index falls within the range of possible indices
# Select the skill level corresponding to the generated index
# Assign the randomly selected value to the corresponding cell in the matched headline


possible_levels = ["Novice", "Beginner", "Intermediate", "Advanced", "Expert"]

average_range = [possible_levels.index("Beginner"), possible_levels.index("Intermediate")]

for index, row in concatenated_df.iterrows():
    matched_skills = row['Matched_skills_samples']
    
    for column in concatenated_df.columns:
        if column in matched_skills:
            mean = np.mean(average_range)  
            std_dev = len(possible_levels) / 3  
                        
            random_index = int(np.random.normal(mean, std_dev))            
            random_index = max(0, min(random_index, len(possible_levels) - 1))
            random_value = possible_levels[random_index]
            concatenated_df.at[index, column] = random_value

# %%
concatenated_df
# Out:
#     Programming_and_Software_Development_off Project_Management_off  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                     Novice               Beginner
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
# ..                                       ...                    ...
# 745                                      NaN                    NaN
# 746                             Intermediate                 Expert
# 747                                      NaN                    NaN
# 748                                      NaN                    NaN
# 749                                   Novice           Intermediate
#
#     Accounting_and_Finance_off Marketing_and_Advertising_off  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                       Novice                        Expert
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ..                         ...                           ...
# 745                        NaN                           NaN
# 746                   Advanced                      Beginner
# 747                        NaN                           NaN
# 748                        NaN                           NaN
# 749                     Expert                        Novice
#
#     Sales_and_Customer_Service_off Human_Resources_and_Leadership_off  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                           Expert                       Intermediate
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ..                             ...                                ...
# 745                            NaN                                NaN
# 746                         Expert                             Novice
# 747                            NaN                                NaN
# 748                            NaN                                NaN
# 749                       Beginner                             Novice
#
#     Graphic_Design_and_Illustration_off Photography_and_Photo_Editing_off  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ..                                  ...                               ...
# 745                                 NaN                               NaN
# 746                                 NaN                               NaN
# 747                                 NaN                               NaN
# 748                                 NaN                               NaN
# 749                                 NaN                               NaN
#
#     Music_instruments_Composition_and_Production_off Writing_and_Editing_off  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
# ..                                               ...                     ...
# 745                                              NaN                     NaN
# 746                                              NaN                     NaN
# 747                                              NaN                     NaN
# 748                                              NaN                     NaN
# 749                                              NaN                     NaN
#
#      ... Literature_and_Philosophy_off  \
# 0    ...                           NaN
# 1    ...                           NaN
# 2    ...                           NaN
# 3    ...                           NaN
# 4    ...                           NaN
# ..   ...                           ...
# 745  ...                        Expert
# 746  ...                           NaN
# 747  ...                           NaN
# 748  ...                        Expert
# 749  ...                           NaN
#
#     Research_Methods_and_Academic_Writing_off  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 745                                    Novice
# 746                                       NaN
# 747                                       NaN
# 748                                    Novice
# 749                                       NaN
#
#     Academic_Reading_and_Critique_off Time_Management_and_Organization_off  \
# 0                                 NaN                             Beginner
# 1                                 NaN                               Novice
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                               Expert
# ..                                ...                                  ...
# 745                            Novice                                  NaN
# 746                               NaN                               Novice
# 747                               NaN                         Intermediate
# 748                      Intermediate                                  NaN
# 749                               NaN                                  NaN
#
#     Stress_Management_and_Mindfulness_off  \
# 0                            Intermediate
# 1                                Advanced
# 2                                     NaN
# 3                                     NaN
# 4                                  Novice
# ..                                    ...
# 745                                   NaN
# 746                              Beginner
# 747                                Expert
# 748                                   NaN
# 749                                   NaN
#
#     Financial_Planning_and_Budgeting_off Self_Defense_and_Personal_Safety_off  \
# 0                                 Novice                             Beginner
# 1                               Advanced                             Beginner
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                           Intermediate                               Novice
# ..                                   ...                                  ...
# 745                                  NaN                                  NaN
# 746                         Intermediate                               Novice
# 747                         Intermediate                         Intermediate
# 748                                  NaN                                  NaN
# 749                                  NaN                                  NaN
#
#     Healthcare_and_Nutrition_off                           Expert_skill  \
# 0                         Expert           Healthcare_and_Nutrition_off
# 1                       Beginner           Electronics_and_Robotics_off
# 2                            NaN          Marketing_and_Advertising_off
# 3                            NaN                 Cooking_and_Baking_off
# 4                         Novice     Leadership_Skills_and_Teamwork_off
# ..                           ...                                    ...
# 745                          NaN          Literature_and_Philosophy_off
# 746                       Novice         Sales_and_Customer_Service_off
# 747                 Intermediate  Stress_Management_and_Mindfulness_off
# 748                          NaN          Literature_and_Philosophy_off
# 749                          NaN             Accounting_and_Finance_off
#
#                                 Matched_skills_samples
# 0    [Time_Management_and_Organization_off, Stress_...
# 1    [Computer_and_Software_Application_Operation_o...
# 2    [Programming_and_Software_Development_off, Pro...
# 3    [Gardening_and_Farming_off, DIY_and_Repairs_of...
# 4    [Time_Management_and_Organization_off, Stress_...
# ..                                                 ...
# 745  [Learning_Foreign_Languages_off, Written_and_O...
# 746  [Programming_and_Software_Development_off, Pro...
# 747  [Time_Management_and_Organization_off, Financi...
# 748  [Computer_and_Software_Application_Operation_o...
# 749  [Programming_and_Software_Development_off, Pro...
#
# [750 rows x 41 columns]

# %%
concatenated_df.to_csv("Skill_Exchange_Offered.csv", index=False)
