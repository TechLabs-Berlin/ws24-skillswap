# %%
from faker import Faker
import pandas as pd
import random

# %%
# Create list of locales that approximately represents the diversity of names in Berlin in faker
# Create an object for the Faker library 
locales = [
    'de_DE',   # German (Germany)
    'tr_TR',   # Turkish (Turkey)
    'en_GB',   # English (United Kingdom)
    'pl_PL',   # Polish (Poland)
    'it_IT',   # Italian (Italy)
]
# Representation of different locales for generating representative name set (educated guess)
probabilities = [0.4, 0.2, 0.1, 0.1, 0.1, 0.05, 0.05]    

# Initialize Faker with custom probabilities
fake = Faker(random_choices=(locales, probabilities))
fake = Faker(locales)

# %%
# Initalize lists to store the data
First_Name = []
EMail = []
Age = []
Gender = []
Coordinate = []
Country = []
City = []
Languages_Preferred = []
Last_Seen = []
Response_Time = []

# %%
# Create realistic e-mail providers including German providers
email_providers = [
    'gmail.com', 'yahoo.com', 'hotmail.com', 'outlook.com', 'aol.com',
    'icloud.com', 'zoho.com', 'protonmail.com', 'mail.com', 'gmx.de',
    'web.de', 't-online.de', 'freenet.de', '1und1.de', 'arcor.de', 'unitybox.de'
]

# %%
# Generate 750 fake names and corresponding email addresses
for _ in range(750):
    first_names = fake.first_name()
    last_names = fake.last_name()
    email = f"{first_names.lower()}.{last_names.lower()}@{fake.random_element(email_providers)}"
    First_Name.append(first_names)
    EMail.append(email)

# %%
# Generate "Ages" 
for _ in range(750):
    ages = random.randint(18, 65)
    Age.append(ages)

# %%
# Generate "Genders"
for _ in range(750):
    # Randomly choose a gender from Male, Female, and Other
    genders = random.choice(["Male", "Female", "Other"])
    Gender.append(genders)

# %%
# Generate "Coordinates" within Berlin
# Berlin Borders
# West: 13.0883
# East: 13.7612
# North: 52.6755
# South: 52.3385


# Function to generate random coordinates within Berlin
def generate_random_coordinates():
    min_longitude = 13.0883
    max_longitude = 13.7612
    min_latitude = 52.3385
    max_latitude = 52.6755
    
    # Generate random latitude and longitude
    latitude = random.uniform(min_latitude, max_latitude)
    longitude = random.uniform(min_longitude, max_longitude)
    
    return latitude, longitude

# %%
# Generate 750 random coordinates in Berlin
for _ in range(750):
    latitude, longitude = generate_random_coordinates()
    Coordinate.append((latitude, longitude))

# %%
# Generate "country" and "city" (Only Germany and Berlin)
for _ in range(750):
    Country.append("Germany")
    City.append("Berlin")

# %%
# Generate "preferred languages" while you can't select more than 5 languages

# Some of the most spoken languages globally and in Europe
most_spoken_languages = [
    "Mandarin Chinese",
    "Spanish",
    "English",
    "Hindi",
    "Arabic",
    "Bengali",
    "Portuguese",
    "Russian",
    "Japanese",
    "Punjabi",
    "German",
    "French",
    "Italian",
    "Polish",
    "Ukrainian",
    "Romanian",
    "German ",
    "Turkish ",
]

# Function to generate a list of languages spoken
def generate_languages_spoken():
    num_languages = random.randint(1, 5)  # Random number of languages between 1 and 5
    languages_spoken = random.sample(most_spoken_languages, min(num_languages, len(most_spoken_languages)))
    return languages_spoken

# Generate languages spoken for 750 individuals
for _ in range(750):
    Languages_Preferred.append(generate_languages_spoken())

# %%
# Create "Last Seen" Data
# Define possible answers
possible_answers = [
    "Recently",
    "Today",
    "Yesterday",
    "Within a Week",
    "Within a Month",
    "Over a Month Ago"
]

for _ in range(750):
    Last_Seen.append(random.choice(possible_answers))

# %%
# Create "Response Time" Data
# Define possible answers
possible_answers = [
    "Within 24 hours",
    "Within a week",
    "Within a month"
]

# Generate the list "Response Time"
Response_Time = []
for _ in range(750):
    Response_Time.append(random.choice(possible_answers))

# %%
# Create Data frame

table = {
    'First_Name': First_Name,
    'EMail': EMail,
    'Age': Age,
    'Gender': Gender,
    'Coordinate': Coordinate,
    'Country': Country,
    'City': City,
    'Languages_Preferred': Languages_Preferred,
    'Last_Seen': Last_Seen,
    'Response_Time': Response_Time
}

Personal_Info = pd.DataFrame(table)
Personal_Info.head(10)
# Out:
#     First_Name                          EMail  Age  Gender  \
# 0        Wanda           wanda.opizzi@aol.com   46    Male
# 1      Meinrad    meinrad.kiedrowicz@zoho.com   26   Other
# 2       Derkay      derkay.kurach@outlook.com   41    Male
# 3        Uzsoy       uzsoy.akdeniz@freenet.de   54    Male
# 4        Alpsü       alpsü.demirel@icloud.com   19  Female
# 5       Nurser        nurser.rymarz@gmail.com   33  Female
# 6  Maksymilian  maksymilian.demir@hotmail.com   20  Female
# 7      Filippo      filippo.szkopek@yahoo.com   51    Male
# 8      Leonard          leonard.mans@zoho.com   62  Female
# 9      Sibylla   sibylla.bandello@hotmail.com   21   Other
#
#                                  Coordinate  Country    City  \
# 0   (52.48592054317992, 13.597034412185927)  Germany  Berlin
# 1   (52.59690466818614, 13.725347983308117)  Germany  Berlin
# 2    (52.56108833495195, 13.18563761680123)  Germany  Berlin
# 3  (52.443532336864735, 13.419956868448828)  Germany  Berlin
# 4    (52.36608543756369, 13.10990718388389)  Germany  Berlin
# 5   (52.63708661533526, 13.093528818781424)  Germany  Berlin
# 6   (52.67477343317099, 13.352122328111756)  Germany  Berlin
# 7    (52.5824339755571, 13.483208315324259)  Germany  Berlin
# 8    (52.34718134180427, 13.16413965393292)  Germany  Berlin
# 9  (52.450292723352696, 13.611517082479065)  Germany  Berlin
#
#                                  Languages_Preferred         Last_Seen  \
# 0  [English, Italian, Ukrainian, Turkish , Romanian]  Over a Month Ago
# 1                 [German, Punjabi, Spanish, Arabic]     Within a Week
# 2                                  [Hindi, Japanese]     Within a Week
# 3                                         [Romanian]     Within a Week
# 4   [Arabic, Portuguese, Mandarin Chinese, Japanese]     Within a Week
# 5                              [Portuguese, Punjabi]  Over a Month Ago
# 6             [Italian, Romanian, Bengali, Japanese]         Yesterday
# 7                                  [German, Spanish]    Within a Month
# 8                                           [German]          Recently
# 9      [Italian, Russian, Arabic, Japanese, English]     Within a Week
#
#      Response_Time
# 0    Within a week
# 1  Within 24 hours
# 2  Within 24 hours
# 3  Within 24 hours
# 4   Within a month
# 5    Within a week
# 6    Within a week
# 7  Within 24 hours
# 8  Within 24 hours
# 9  Within 24 hours

# %%
Personal_Info.to_csv('Personal_Info.csv', index=False)
