# %%
from faker import Faker
import pandas as pd
import random

# %%
# Create list of locales that approximately represents the diversity of names in Berlin in faker
# Create an object for the Faker library 
locales = [
    'de_DE',   # German (Germany)
    'tr_TR',   # Turkish (Turkey)
    'en_GB',   # English (United Kingdom)
    'pl_PL',   # Polish (Poland)
    'it_IT',   # Italian (Italy)
]
# Representation of different locales for generating representative name set (educated guess)
probabilities = [0.4, 0.2, 0.1, 0.1, 0.1, 0.05, 0.05]    

# Initialize Faker with custom probabilities
fake = Faker(random_choices=(locales, probabilities))
fake = Faker(locales)

# %%
# Initalize lists to store the data
First_Name = []
EMail = []
Age = []
Gender = []
Location_Preferences = []
Coordinate = []
Country = []
City = []
Languages_Preferred = []
Last_Seen = []
Response_Time = []

# %%
# Create realistic e-mail providers including German providers
email_providers = [
    'gmail.com', 'yahoo.com', 'hotmail.com', 'outlook.com', 'aol.com',
    'icloud.com', 'zoho.com', 'protonmail.com', 'mail.com', 'gmx.de',
    'web.de', 't-online.de', 'freenet.de', '1und1.de', 'arcor.de', 'unitybox.de'
]

# %%
# Generate 750 fake names and corresponding email addresses
for _ in range(750):
    first_names = fake.first_name()
    last_names = fake.last_name()
    email = f"{first_names.lower()}.{last_names.lower()}@{fake.random_element(email_providers)}"
    First_Name.append(first_names)
    EMail.append(email)

# %%
# Generate "Ages" 
for _ in range(750):
    ages = random.randint(18, 65)
    Age.append(ages)

# %%
# Generate "Genders"
for _ in range(750):
    # Randomly choose a gender from Male, Female, and Other
    genders = random.choice(["Male", "Female", "Other"])
    Gender.append(genders)

# %%
# Generate "Location Preferences"
for _ in range(750):
    preference = random.choice(["Local Only", "Remote Only", "Local or Remote"])
    Location_Preferences.append(preference)

# %%
# Generate "Coordinates" within Berlin
# Berlin Borders
# West: 13.0883
# East: 13.7612
# North: 52.6755
# South: 52.3385


# Function to generate random coordinates within Berlin
def generate_random_coordinates():
    min_longitude = 13.0883
    max_longitude = 13.7612
    min_latitude = 52.3385
    max_latitude = 52.6755
    
    # Generate random latitude and longitude
    latitude = random.uniform(min_latitude, max_latitude)
    longitude = random.uniform(min_longitude, max_longitude)
    
    return latitude, longitude

# %%
# Generate 750 random coordinates in Berlin
for _ in range(750):
    latitude, longitude = generate_random_coordinates()
    Coordinate.append((latitude, longitude))

# %%
# Generate "country" and "city" (Only Germany and Berlin)
for _ in range(750):
    Country.append("Germany")
    City.append("Berlin")

# %%
# Generate "preferred languages" while you can't select more than 5 languages

# Some of the most spoken languages globally and in Europe
most_spoken_languages = [
    "Mandarin Chinese",
    "Spanish",
    "English",
    "Hindi",
    "Arabic",
    "Bengali",
    "Portuguese",
    "Russian",
    "Japanese",
    "Punjabi",
    "German",
    "French",
    "Italian",
    "Polish",
    "Ukrainian",
    "Romanian",
    "Turkish",
]

# Function to generate a list of languages spoken
def generate_languages_spoken():
    num_languages = random.randint(1, 5)  # Random number of languages between 1 and 5
    languages_spoken = random.sample(most_spoken_languages, min(num_languages, len(most_spoken_languages)))
    return languages_spoken

# Generate languages spoken for 750 individuals
for _ in range(750):
    Languages_Preferred.append(generate_languages_spoken())

# %%
# Create "Last Seen" Data
# Define possible answers
possible_answers = [
    "Recently",
    "Today",
    "Yesterday",
    "Within a Week",
    "Within a Month",
    "Over a Month Ago"
]

for _ in range(750):
    Last_Seen.append(random.choice(possible_answers))

# %%
# Create "Response Time" Data
# Define possible answers
possible_answers = [
    "Within 24 hours",
    "Within a week",
    "Within a month"
]

# Generate the list "Response Time"
Response_Time = []
for _ in range(750):
    Response_Time.append(random.choice(possible_answers))

# %%
# Create Data frame

table = {
    'First_Name': First_Name,
    'EMail': EMail,
    'Age': Age,
    'Gender': Gender,
    'Location_Preferences' : Location_Preferences,
    'Coordinate': Coordinate,
    'Country': Country,
    'City': City,
    'Languages_Preferred': Languages_Preferred,
    'Last_Seen': Last_Seen,
    'Response_Time': Response_Time
}

Personal_Info = pd.DataFrame(table)
Personal_Info.head(10)
# Out:
#    First_Name                           EMail  Age  Gender  \
# 0   Tymoteusz      tymoteusz.murray@gmail.com   51   Other
# 1  Anne-Marie     anne-marie.guarato@mail.com   27    Male
# 2    Nazlihan  nazlihan.littizzetto@yahoo.com   42  Female
# 3     Carmelo         carmelo.babato@arcor.de   58    Male
# 4    Tutkucan       tutkucan.karge@icloud.com   55   Other
# 5        Sina        sina.mitchell@freenet.de   30    Male
# 6      Hubert             hubert.bilir@gmx.de   28  Female
# 7        Lynn           lynn.demirel@arcor.de   36  Female
# 8   Tymoteusz        tymoteusz.ülker@mail.com   49   Other
# 9        Katy                katy.page@web.de   28   Other
#
#   Location_Preferences                                Coordinate  Country  \
# 0           Local Only    (52.61055179270523, 13.21377580760253)  Germany
# 1           Local Only  (52.411841312390216, 13.754020527691711)  Germany
# 2      Local or Remote   (52.46021525312517, 13.289798400558723)  Germany
# 3          Remote Only    (52.67290557991128, 13.13237868754457)  Germany
# 4          Remote Only    (52.58955980655409, 13.29518537953884)  Germany
# 5      Local or Remote  (52.653313993316345, 13.254232345795497)  Germany
# 6           Local Only   (52.402684601216066, 13.32402541791881)  Germany
# 7      Local or Remote  (52.585218712735724, 13.097762811928924)  Germany
# 8          Remote Only   (52.44136664626803, 13.576206355242311)  Germany
# 9          Remote Only    (52.4741446219924, 13.704420826197525)  Germany
#
#      City                                Languages_Preferred       Last_Seen  \
# 0  Berlin     [Turkish, Portuguese, Bengali, French, Arabic]       Yesterday
# 1  Berlin  [Bengali, Mandarin Chinese, Japanese, German, ...   Within a Week
# 2  Berlin                        [English, Romanian, French]  Within a Month
# 3  Berlin      [Romanian, Polish, Russian, English, Spanish]        Recently
# 4  Berlin      [English, Polish, Ukrainian, Japanese, Hindi]   Within a Week
# 5  Berlin          [Turkish, Hindi, French, Arabic, Spanish]   Within a Week
# 6  Berlin         [German, Punjabi, Arabic, Polish, English]        Recently
# 7  Berlin                                          [Russian]        Recently
# 8  Berlin       [Turkish, Russian, Bengali, Arabic, Spanish]  Within a Month
# 9  Berlin                     [Ukrainian, Romanian, Russian]        Recently
#
#      Response_Time
# 0    Within a week
# 1  Within 24 hours
# 2    Within a week
# 3  Within 24 hours
# 4    Within a week
# 5  Within 24 hours
# 6    Within a week
# 7    Within a week
# 8    Within a week
# 9    Within a week

# %%
Personal_Info.to_csv('Personal_Info.csv', index=False)
