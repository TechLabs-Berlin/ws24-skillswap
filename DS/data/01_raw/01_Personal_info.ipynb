# %%
from faker import Faker
import pandas as pd
import random

# %%
# Create list of locales to account for the diversity of names in Berlin in faker (not representative)
# Restriction to Latin alphabet for simplicity (note that this leads to underrepresentation)
# Create an object for the Faker library 
locales = [
    'de_DE',   # German (Germany)
    'tr_TR',   # Turkish (Turkey)
    'en_GB',   # English (United Kingdom)
    'pl_PL',   # Polish (Poland)
    'it_IT',   # Italian (Italy)
    'fr_FR',   # French (France)
    'es_ES',   # Spanish (Spain)
    'pt_PT'    # Portuguese (Portugal)
]
# Representation of different locales for generating representative name set (guess)
probabilities = [0.6, 0.1, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# Initialize Faker with custom probabilities
fake = Faker(random_choices=(locales, probabilities))
fake = Faker(locales)

# %%
# Initalize lists to store the data
First_Name = []
EMail = []
Age = []
Gender = []
Location_Preferences = []
Coordinate = []
Country = []
City = []
Languages_Preferred = []
Last_Seen = []
Response_Time = []

# %%
# Create realistic e-mail providers including German providers
email_providers = [
    'gmail.com', 'yahoo.com', 'hotmail.com', 'outlook.com', 'aol.com',
    'icloud.com', 'zoho.com', 'protonmail.com', 'mail.com', 'gmx.de',
    'web.de', 't-online.de', 'freenet.de', '1und1.de', 'arcor.de', 'unitybox.de'
]

# %%
# Generate 750 fake names and corresponding email addresses
for _ in range(750):
    first_names = fake.first_name()
    last_names = fake.last_name()
    email = f"{first_names.lower()}.{last_names.lower()}@{fake.random_element(email_providers)}"
    First_Name.append(first_names)
    EMail.append(email)

# %%
# Generate "Ages" 
for _ in range(750):
    ages = random.randint(18, 65)
    Age.append(ages)

# %%
# Generate "Genders"
for _ in range(750):
    # Randomly choose a gender from Male, Female, and Other
    genders = random.choice(["Male", "Female", "Other"])
    Gender.append(genders)

# %%
# Generate "Location Preferences"
for _ in range(750):
    preference = random.choice(["Local Only", "Remote Only", "Local or Remote"])
    Location_Preferences.append(preference)

# %%
# Generate "Coordinates" within Berlin
# Berlin Borders
# West: 13.0883
# East: 13.7612
# North: 52.6755
# South: 52.3385


# Function to generate random coordinates within Berlin
def generate_random_coordinates():
    min_longitude = 13.0883
    max_longitude = 13.7612
    min_latitude = 52.3385
    max_latitude = 52.6755
    
    # Generate random latitude and longitude
    latitude = random.uniform(min_latitude, max_latitude)
    longitude = random.uniform(min_longitude, max_longitude)
    
    return latitude, longitude

# %%
# Generate 750 random coordinates in Berlin
for _ in range(750):
    latitude, longitude = generate_random_coordinates()
    Coordinate.append((latitude, longitude))

# %%
# Generate "country" and "city" (Only Germany and Berlin)
for _ in range(750):
    Country.append("Germany")
    City.append("Berlin")

# %%
# Generate "preferred languages" while you can't select more than 5 languages

# Some of the most spoken languages globally and in Europe
most_spoken_languages = [
    "Mandarin Chinese",
    "Spanish",
    "English",
    "Hindi",
    "Arabic",
    "Bengali",
    "Portuguese",
    "Russian",
    "Japanese",
    "Punjabi",
    "German",
    "French",
    "Italian",
    "Polish",
    "Ukrainian",
    "Romanian",
    "Turkish",
]

# Function to generate a list of languages spoken
def generate_languages_spoken():
    num_languages = random.randint(1, 5)  # Random number of languages between 1 and 5
    languages_spoken = random.sample(most_spoken_languages, min(num_languages, len(most_spoken_languages)))
    return languages_spoken

# Generate languages spoken for 750 individuals
for _ in range(750):
    Languages_Preferred.append(generate_languages_spoken())

# %%
# Create "Last Seen" Data
# Define possible answers
possible_answers = [
    "Recently",
    "Today",
    "Yesterday",
    "Within a Week",
    "Within a Month",
    "Over a Month Ago"
]

for _ in range(750):
    Last_Seen.append(random.choice(possible_answers))

# %%
# Create "Response Time" Data
# Define possible answers
possible_answers = [
    "Within 24 hours",
    "Within a week",
    "Within a month"
]

# Generate the list "Response Time"
Response_Time = []
for _ in range(750):
    Response_Time.append(random.choice(possible_answers))

# %%
# Create Data frame

table = {
    'First_Name': First_Name,
    'EMail': EMail,
    'Age': Age,
    'Gender': Gender,
    'Location_Preferences' : Location_Preferences,
    'Coordinate': Coordinate,
    'Country': Country,
    'City': City,
    'Languages_Preferred': Languages_Preferred,
    'Last_Seen': Last_Seen,
    'Response_Time': Response_Time
}

Personal_Info = pd.DataFrame(table)
Personal_Info.head(10)
# Out:
#   First_Name                        EMail  Age  Gender Location_Preferences  \
# 0     Blanka      blanka.diallo@gmail.com   41   Other      Local or Remote
# 1     Franca        franca.pires@arcor.de   56    Male           Local Only
# 2     Afonso     afonso.çorlu@outlook.com   21    Male           Local Only
# 3      Bruno  bruno.tirabassi@outlook.com   63   Other          Remote Only
# 4      Çamok       çamok.amorós@yahoo.com   27  Female          Remote Only
# 5    Thérèse      thérèse.durand@1und1.de   32    Male           Local Only
# 6       Íris         íris.siatka@zoho.com   36  Female      Local or Remote
# 7     Marcel       marcel.powała@mail.com   32  Female           Local Only
# 8     Rufino        rufino.ülker@1und1.de   21  Female           Local Only
# 9  Sebastião      sebastião.köster@web.de   32  Female           Local Only
#
#                                  Coordinate  Country    City  \
# 0   (52.65020750727031, 13.453950162658447)  Germany  Berlin
# 1   (52.46157199672177, 13.435252146512347)  Germany  Berlin
# 2  (52.350807193977225, 13.314727050180634)  Germany  Berlin
# 3  (52.648861355776965, 13.693866938215589)  Germany  Berlin
# 4   (52.379103527572475, 13.42899473628895)  Germany  Berlin
# 5   (52.670142344557156, 13.57259557005475)  Germany  Berlin
# 6   (52.61354186916493, 13.458007907930059)  Germany  Berlin
# 7   (52.45977986440862, 13.385402767815785)  Germany  Berlin
# 8   (52.57688731269562, 13.549165346470202)  Germany  Berlin
# 9   (52.43143434073895, 13.760605409258273)  Germany  Berlin
#
#                                  Languages_Preferred       Last_Seen  \
# 0  [Romanian, Portuguese, Italian, Punjabi, Spanish]  Within a Month
# 1                                          [English]        Recently
# 2        [Japanese, French, Punjabi, Russian, Hindi]           Today
# 3                         [Polish, Mandarin Chinese]       Yesterday
# 4              [Japanese, Bengali, Punjabi, Turkish]       Yesterday
# 5                        [Spanish, Japanese, French]       Yesterday
# 6                                       [Portuguese]           Today
# 7    [Portuguese, Spanish, Mandarin Chinese, Arabic]        Recently
# 8     [Japanese, Punjabi, English, French, Romanian]        Recently
# 9                 [Hindi, Bengali, Japanese, Arabic]        Recently
#
#      Response_Time
# 0   Within a month
# 1  Within 24 hours
# 2  Within 24 hours
# 3    Within a week
# 4    Within a week
# 5  Within 24 hours
# 6   Within a month
# 7  Within 24 hours
# 8  Within 24 hours
# 9    Within a week

# %%
Personal_Info.to_csv('Personal_Info.csv', index=False)
