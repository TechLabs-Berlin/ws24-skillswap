# %%
import random
import pandas as pd
import numpy as np

# %%
# Define the skill domains or categories
# Pick a random number between 1 and 3
# Select 1 to 3 random skill domains (based on the picked number) 
# Generate 800 random skill domain samples


skill_domains = [
    "Agriculture",
    "Animal Care",
    "Art",
    "Beauty",
    "Dance",
    "Music",
    "Writing",
    "Language",
    "Health",
    "Sports",
    "Food",
    "Technology",
    "Photo",
    "Video"
]

def select_random_skills():
    num_skills = random.randint(1, 3)
    selected_skills = random.sample(skill_domains, num_skills)
    return selected_skills

random_skill_samples = []

for _ in range(800):
    random_skills = select_random_skills()
    random_skill_samples.append(random_skills)
    
print(random_skill_samples)
# Out:
# [['Food', 'Sports', 'Beauty'], ['Music', 'Animal Care', 'Dance'], ['Health', 'Food', 'Dance'], ['Sports', 'Agriculture', 'Health'], ['Writing', 'Music'], ['Agriculture', 'Language'], ['Music', 'Beauty', 'Writing'], ['Video'], ['Agriculture', 'Writing'], ['Technology', 'Animal Care', 'Language'], ['Health', 'Agriculture'], ['Food', 'Language'], ['Sports'], ['Health'], ['Agriculture'], ['Health', 'Language'], ['Food', 'Video'], ['Sports', 'Health', 'Agriculture'], ['Music', 'Agriculture', 'Writing'], ['Food', 'Health'], ['Food', 'Art', 'Dance'], ['Health'], ['Photo', 'Art'], ['Dance'], ['Dance'], ['Beauty', 'Food', 'Technology'], ['Dance', 'Beauty'], ['Beauty'], ['Video'], ['Agriculture', 'Animal Care'], ['Music', 'Video'], ['Food'], ['Beauty'], ['Video', 'Beauty', 'Technology'], ['Art', 'Agriculture', 'Beauty'], ['Sports'], ['Dance', 'Music', 'Language'], ['Music', 'Beauty', 'Dance'], ['Agriculture', 'Food', 'Writing'], ['Agriculture'], ['Agriculture'], ['Language'], ['Food', 'Animal 
# ...

# %%
Domains_df = pd.DataFrame({"Skill Domains": random_skill_samples})
Domains_df
# Out:
#                      Skill Domains
# 0           [Food, Sports, Beauty]
# 1      [Music, Animal Care, Dance]
# 2            [Health, Food, Dance]
# 3    [Sports, Agriculture, Health]
# 4                 [Writing, Music]
# ..                             ...
# 795  [Language, Photo, Technology]
# 796           [Health, Technology]
# 797                         [Food]
# 798      [Technology, Food, Dance]
# 799            [Dance, Technology]
#
# [800 rows x 1 columns]

# %%
# Skill domains and respective skills in skill portfolio of user -> marked with ending "_off" for "offered"
skills_dict = {
    'Agriculture': ['Farming_off', 'Fishery_off', 'Gardening_off'],
    'Animal Care': ['Pet grooming_off', 'Pet training_off'],
    'Art': ['Drawing_off', 'Painting_off', 'Sculpture_off', 'Print making_off', 'Poetry_off'],
    'Beauty': ['Make-up_off', 'Facials_off', 'Pedicure & Manicure_off', 'Hair care_off'],
    'Dance': ['Ballet_off', 'Tap dance_off', 'Jazz dance_off', 'Salsa_off', 'Ballroom dance_off'],
    'Music': ['Piano_off', 'Guitar_off', 'Drumming_off', 'Trumpet_off', 'Composing_off'],
    'Writing': ['Script writing_off', 'Play writing_off', 'Poetry writing_off', 'Caligraphy_off', 'Blogging_off', 'Journalism_off'],
    'Language': ['German_off', 'Spanish_off', 'Arabic_off', 'French_off', 'English_off'],
    'Health': ['Nutrition_off', 'Fitness & Excercise_off', 'Wellness_off'],
    'Sports': ['Tennis_off', 'Football_off', 'Basketball_off', 'Yoga_off', 'Baseball_off', 'Gymnastic_off'],
    'Food': ['Cooking_off', 'Baking_off', 'Grilling_off', 'Meal planning_off', 'Sautéing_off'],
    'Technology': ['Programming_off', 'Graphic design_off', 'Data Analysis_off', 'Photoshop_off', 'Social Media_off'],
    'Photo': ['Camera handling_off', 'Photo editing_off', 'Lighting_off', 'Landscape photography_off', 'Portrait photography_off', 'Image processing_off'],
    'Video': ['Video editing_off', 'Film making_off', 'Animation_off', 'Motion graphics_off', 'Visual effects_off']
}

# %%
# For every (randomly selected) skill domain of a user, get the respective skills from the skills_dict() 

# Initialize a list to store the matched skills for each domain sample
# Iterate through each domain sample in random_skill_samples

# Initialize an empty list to store the matched skills for the current sample
# Iterate through each skill domain in the current sample

# Retrieve the matching skills from skills_dict and extend the matched_skills list
# Append the matched skills for the current sample to the matched_skills_samples list

matched_skills_samples = []

for sample in random_skill_samples:
    matched_skills = []
    for skill_domain in sample:
        matched_skills.extend(skills_dict.get(skill_domain, []))
    matched_skills_samples.append(matched_skills)
    
    
print(matched_skills_samples)
# Out:
# [['Cooking_off', 'Baking_off', 'Grilling_off', 'Meal planning_off', 'Sautéing_off', 'Tennis_off', 'Football_off', 'Basketball_off', 'Yoga_off', 'Baseball_off', 'Gymnastic_off', 'Make-up_off', 'Facials_off', 'Pedicure & Manicure_off', 'Hair care_off'], ['Piano_off', 'Guitar_off', 'Drumming_off', 'Trumpet_off', 'Composing_off', 'Pet grooming_off', 'Pet training_off', 'Ballet_off', 'Tap dance_off', 'Jazz dance_off', 'Salsa_off', 'Ballroom dance_off'], ['Nutrition_off', 'Fitness & Excercise_off', 'Wellness_off', 'Cooking_off', 'Baking_off', 'Grilling_off', 'Meal planning_off', 'Sautéing_off', 'Ballet_off', 'Tap dance_off', 'Jazz dance_off', 'Salsa_off', 'Ballroom dance_off'], ['Tennis_off', 'Football_off', 'Basketball_off', 'Yoga_off', 'Baseball_off', 'Gymnastic_off', 'Farming_off', 'Fishery_off', 'Gardening_off', 'Nutrition_off', 'Fitness & Excercise_off', 'Wellness_off'], ['Script writing_off', 'Play writing_off', 'Poetry writing_off', 'Caligraphy_off', 'Blogging_off', 'Journalism_off'
# ...

# %%
Matched_skills_df = pd.DataFrame({"Matched_skills_samples": matched_skills_samples})
Matched_skills_df
# Out:
#                                 Matched_skills_samples
# 0    [Cooking_off, Baking_off, Grilling_off, Meal p...
# 1    [Piano_off, Guitar_off, Drumming_off, Trumpet_...
# 2    [Nutrition_off, Fitness & Excercise_off, Welln...
# 3    [Tennis_off, Football_off, Basketball_off, Yog...
# 4    [Script writing_off, Play writing_off, Poetry ...
# ..                                                 ...
# 795  [German_off, Spanish_off, Arabic_off, French_o...
# 796  [Nutrition_off, Fitness & Excercise_off, Welln...
# 797  [Cooking_off, Baking_off, Grilling_off, Meal p...
# 798  [Programming_off, Graphic design_off, Data Ana...
# 799  [Ballet_off, Tap dance_off, Jazz dance_off, Sa...
#
# [800 rows x 1 columns]

# %%
# Select a random expert skill where the user has experience and is able to teach others

# Initialize a list to store the randomly selected skills
# Iterate over each row in the DataFrame
# Extract the list of matched skills from the current row
# Check if the list of matched skills is not empty
# Select a random skill from the list
# Append the randomly selected skill to the new list
# If the list of matched skills is empty, append None 

expert_skill = []

for index, row in Matched_skills_df.iterrows():
    matched_skills = row['Matched_skills_samples']
    
    if matched_skills:
        random_skill = random.choice(matched_skills)
        expert_skill.append(random_skill)
    else:
        expert_skill.append(None)

# %%
Expert_df = pd.DataFrame({"Expert_skill": expert_skill})
Expert_df
# Out:
#            Expert_skill
# 0         Gymnastic_off
# 1         Composing_off
# 2        Jazz dance_off
# 3         Gardening_off
# 4    Script writing_off
# ..                  ...
# 795   Photo editing_off
# 796       Photoshop_off
# 797         Cooking_off
# 798       Tap dance_off
# 799           Salsa_off
#
# [800 rows x 1 columns]

# %%
# Define the columns of the final dataframe to then fill them with input 

Farming_off = []
Fishery_off = []
Gardening_off = []
Pet_grooming_off = []
Pet_training_off = []
Drawing_off = []
Painting_off = []
Sculpture_off = []
Print_making_off = []
Poetry_off = []
Make_up_off = []
Facials_off = []
Pedicure_and_Manicure_off = []
Hair_care_off = []
Ballet_off = []
Tap_dance_off = []
Jazz_dance_off = []
Salsa_off = []
Ballroom_dance_off = []
Piano_off = []
Guitar_off = []
Drumming_off = []
Trumpet_off = []
Composing_off = []
Script_writing_off = []
Play_writing_off = []
Poetry_writing_off = []
Caligraphy_off = []
Blogging_off = []
Journalism_off = []
German_off = []
Spanish_off = []
Arabic_off = []
French_off = []
English_off = []
Nutrition_off = []
Fitness_and_Excercise_off = []
Wellness_off = []
Tennis_off = []
Football_off = []
Basketball_off = []
Yoga_off = []
Baseball_off = []
Gymnastic_off = []
Cooking_off = []
Baking_off = []
Grilling_off = []
Meal_planning_off = []
Sautéing_off = []
Programming_off = []
Graphic_design_off = []
Data_Analysis_off = []
Photoshop_off = []
Social_Media_off = []
Camera_handling_off = []
Photo_editing_off = []
Lighting_off = []
Landscape_photography_off = []
Portrait_photography_off = []
Image_processing_off = []
Video_editing_off = []
Film_making_off = []
Animation_off = []
Motion_graphics_off = []
Visual_effects_off = []

# %%
skill_table = {
    
    "Farming_off": Farming_off,
    "Fishery_off": Fishery_off,
    "Gardening_off": Gardening_off,
    "Pet grooming_off": Pet_grooming_off,
    "Pet training_off": Pet_training_off,
    "Drawing_off": Drawing_off,
    "Painting_off": Painting_off,
    "Sculpture_off": Sculpture_off,
    "Print making_off": Print_making_off,
    "Poetry_off": Poetry_off,
    "Make-up_off": Make_up_off,
    "Facials_off": Facials_off,
    "Pedicure & Manicure_off": Pedicure_and_Manicure_off,
    "Hair care_off": Hair_care_off,
    "Ballet_off": Ballet_off,
    "Tap dance_off": Tap_dance_off,
    "Jazz dance_off": Jazz_dance_off,
    "Salsa_off": Salsa_off,
    "Ballroom dance_off": Ballroom_dance_off,
    "Piano_off": Piano_off,
    "Guitar_off": Guitar_off,
    "Drumming_off": Drumming_off,
    "Trumpet_off": Trumpet_off,
    "Composing_off": Composing_off,
    "Script writing_off": Script_writing_off,
    "Play writing_off": Play_writing_off,
    "Poetry writing_off": Poetry_writing_off,
    "Caligraphy_off": Caligraphy_off,
    "Blogging_off": Blogging_off,
    "Journalism_off": Journalism_off,
    "German_off": German_off,
    "Spanish_off": Spanish_off,
    "Arabic_off": Arabic_off,
    "French_off": French_off,
    "English_off": English_off,
    "Nutrition_off": Nutrition_off,
    "Fitness & Excercise_off": Fitness_and_Excercise_off,
    "Wellness_off": Wellness_off,
    "Tennis_off": Tennis_off,
    "Football_off": Football_off,
    "Basketball_off": Basketball_off,
    "Yoga_off": Yoga_off,
    "Baseball_off": Baseball_off,
    "Gymnastic_off": Gymnastic_off,
    "Cooking_off": Cooking_off,
    "Baking_off": Baking_off,
    "Grilling_off": Grilling_off,
    "Meal planning_off": Meal_planning_off,
    "Sautéing_off": Sautéing_off,
    "Programming_off": Programming_off,
    "Graphic design_off": Graphic_design_off,
    "Data Analysis_off": Data_Analysis_off,
    "Photoshop_off": Photoshop_off,
    "Social Media_off": Social_Media_off,
    "Camera handling_off": Camera_handling_off,
    "Photo editing_off": Photo_editing_off,
    "Lighting_off": Lighting_off,
    "Landscape photography_off": Landscape_photography_off,
    "Portrait photography_off": Portrait_photography_off,
    "Image processing_off": Image_processing_off,
    "Video editing_off": Video_editing_off,
    "Film making_off": Film_making_off,
    "Animation_off": Animation_off,
    "Motion graphics_off": Motion_graphics_off,
    "Visual effects_off": Visual_effects_off
}


Skills_Offered = pd.DataFrame(skill_table)

Skills_Offered.head()
# Out:
# Empty DataFrame
# ...

# %%
concatenated_df = pd.concat([Skills_Offered, Expert_df, Matched_skills_df, Domains_df], axis=1)
concatenated_df
# Out:
#      Farming_off  Fishery_off  Gardening_off  Pet grooming_off  \
# 0            NaN          NaN            NaN               NaN
# 1            NaN          NaN            NaN               NaN
# 2            NaN          NaN            NaN               NaN
# 3            NaN          NaN            NaN               NaN
# 4            NaN          NaN            NaN               NaN
# ..           ...          ...            ...               ...
# 795          NaN          NaN            NaN               NaN
# 796          NaN          NaN            NaN               NaN
# 797          NaN          NaN            NaN               NaN
# 798          NaN          NaN            NaN               NaN
# 799          NaN          NaN            NaN               NaN
#
#      Pet training_off  Drawing_off  Painting_off  Sculpture_off  \
# 0                 NaN          NaN           NaN            NaN
# 1                 NaN          NaN           NaN            NaN
# ...

# %%
# Next, the skill level of a user in the respective skills will be defined
# Make sure that a person is an expert in at least one skill 

# Extract the value in the "expert_skill" column for the current row
# Iterate over each column in the DataFrame
# Check if the column name matches the expert skill
# Assign "Expert" to the corresponding cell in the matched column

for index, row in concatenated_df.iterrows():
    expert_skill = row['Expert_skill']
    
    for column in concatenated_df.columns:
        if column == expert_skill:
            concatenated_df.at[index, column] = "Expert"
# Out:
# C:\Users\Johannes\AppData\Local\Temp\ipykernel_15344\1762000204.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Expert' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   concatenated_df.at[index, column] = "Expert"

# %%
# Remove the expert skill from the Matched Skills column to make sure the skill level is not overwritten in the next step

# Iterate over each row in the DataFrame
# Extract the value in the "Expert_Level" column for the current row
# Extract the list of matched skills from the "Matched_skills_samples" column
# Check if the value in the "Expert_Level" column is not null
# Remove the value in "Expert_Level" from the list of matched skills, if it exists
# Update the "Matched_skills_samples" column with the modified list of matched skills


for index, row in concatenated_df.iterrows():
    expert_level = row['Expert_skill']
    
    matched_skills = row['Matched_skills_samples']
    
    if pd.notnull(expert_level):
        if expert_level in matched_skills:
            matched_skills.remove(expert_level)
    
    concatenated_df.at[index, 'Matched_skills_samples'] = matched_skills

# %%
concatenated_df
# Out:
#     Farming_off Fishery_off Gardening_off Pet grooming_off Pet training_off  \
# 0           NaN         NaN           NaN              NaN              NaN
# 1           NaN         NaN           NaN              NaN              NaN
# 2           NaN         NaN           NaN              NaN              NaN
# 3           NaN         NaN        Expert              NaN              NaN
# 4           NaN         NaN           NaN              NaN              NaN
# ..          ...         ...           ...              ...              ...
# 795         NaN         NaN           NaN              NaN              NaN
# 796         NaN         NaN           NaN              NaN              NaN
# 797         NaN         NaN           NaN              NaN              NaN
# 798         NaN         NaN           NaN              NaN              NaN
# 799         NaN         NaN           NaN              NaN              NaN
#
# ...

# %%
# Randomly select a value from possible_levels with a normal distribution to 
# fill the columns (where a person has a skill) with skill levels
# Define possible skill levels
# Assumption: Usually people are beginners in the fields where they are not Experts (That's why they are on the platform)
# Iterate over each row in the DataFrame
# Extract the list of matched skills from the current row
# Iterate over each column in the DataFrame
# Check if the column name matches any of the skills in matched_skills
# Define parameters for the normal distribution
# Generate random index from a normal distribution
# Ensure the index falls within the range of possible indices
# Select the skill level corresponding to the generated index
# Assign the randomly selected value to the corresponding cell in the matched headline


possible_levels = ["Novice", "Beginner", "Intermediate", "Advanced", "Expert"]

average_range = [possible_levels.index("Beginner"), possible_levels.index("Intermediate")]

for index, row in concatenated_df.iterrows():
    matched_skills = row['Matched_skills_samples']
    
    for column in concatenated_df.columns:
        if column in matched_skills:
            mean = np.mean(average_range)  
            std_dev = len(possible_levels) / 3  
                        
            random_index = int(np.random.normal(mean, std_dev))            
            random_index = max(0, min(random_index, len(possible_levels) - 1))
            random_value = possible_levels[random_index]
            concatenated_df.at[index, column] = random_value

# %%
concatenated_df
# Out:
#     Farming_off Fishery_off Gardening_off Pet grooming_off Pet training_off  \
# 0           NaN         NaN           NaN              NaN              NaN
# 1           NaN         NaN           NaN         Beginner           Novice
# 2           NaN         NaN           NaN              NaN              NaN
# 3        Novice      Novice        Expert              NaN              NaN
# 4           NaN         NaN           NaN              NaN              NaN
# ..          ...         ...           ...              ...              ...
# 795         NaN         NaN           NaN              NaN              NaN
# 796         NaN         NaN           NaN              NaN              NaN
# 797         NaN         NaN           NaN              NaN              NaN
# 798         NaN         NaN           NaN              NaN              NaN
# 799         NaN         NaN           NaN              NaN              NaN
#
# ...

# %%
concatenated_df.to_csv("Skill_Exchange_Offered.csv", index=False)
