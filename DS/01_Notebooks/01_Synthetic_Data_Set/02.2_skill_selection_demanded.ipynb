# %%
import random
import pandas as pd
import numpy as np

# %%
# Define the skill domains
# Pick a random number between 1 and 5
# Select random skill domains
# Generate 10000 random skill domain samples


skill_domains = [
  "Agriculture",
    "Animal Care",
    "Art",
    "Beauty",
    "Dance",
    "Music",
    "Writing",
    "Language",
    "Health",
    "Sports",
    "Food",
    "Technology",
    "Photo",
    "Video"
]

def select_random_skills():
    num_skills = random.randint(1, 5)

    selected_skills = random.sample(skill_domains, num_skills)
    
    return selected_skills

random_skill_samples = []

for _ in range(10000):
    random_skills = select_random_skills()
    random_skill_samples.append(random_skills)
    
print(random_skill_samples)
# Out:
# [['Food', 'Art', 'Agriculture'], ['Music', 'Food', 'Agriculture', 'Photo', 'Health'], ['Animal Care', 'Technology', 'Writing'], ['Beauty', 'Music', 'Language', 'Writing', 'Art'], ['Video', 'Health', 'Beauty', 'Dance'], ['Agriculture', 'Photo', 'Technology', 'Beauty', 'Food'], ['Beauty', 'Technology'], ['Writing'], ['Beauty'], ['Writing', 'Agriculture', 'Health'], ['Health', 'Food', 'Video', 'Photo', 'Language'], ['Technology'], ['Language', 'Sports', 'Health', 'Writing', 'Music'], ['Health'], ['Writing'], ['Technology', 'Writing', 'Food', 'Animal Care'], ['Agriculture', 'Sports', 'Photo', 'Beauty'], ['Writing', 'Health'], ['Dance', 'Art', 'Language'], ['Food', 'Technology'], ['Beauty', 'Dance', 'Writing', 'Art', 'Animal Care'], ['Technology', 'Writing', 'Video'], ['Food', 'Animal Care', 'Technology'], ['Video', 'Writing'], ['Video', 'Art'], ['Music', 'Photo', 'Dance', 'Health', 'Sports'], ['Video', 'Technology', 'Agriculture'], ['Dance', 'Health', 'Video', 'Writing', 'Art'], ['Art'],
# ...

# %%
# Skill domains and respective skills
skills_dict = {
    'Agriculture': ['Farming_dem', 'Fishery_dem', 'Gardening_dem'],
    'Animal Care': ['Pet grooming_dem', 'Pet training_dem'],
    'Art': ['Drawing_dem', 'Painting_dem', 'Sculpture_dem', 'Print making_dem', 'Poetry_dem'],
    'Beauty': ['Make-up_dem', 'Facials_dem', 'Pedicure & Manicure_dem', 'Hair care_dem'],
    'Dance': ['Ballet_dem', 'Tap dance_dem', 'Jazz dance_dem', 'Salsa_dem', 'Ballroom dance_dem'],
    'Music': ['Piano_dem', 'Guitar_dem', 'Drumming_dem', 'Trumpet_dem', 'Composing_dem'],
    'Writing': ['Script writing_dem', 'Play writing_dem', 'Poetry writing_dem', 'Caligraphy_dem', 'Blogging_dem', 'Journalism_dem'],
    'Language': ['German_dem', 'Spanish_dem', 'Arabic_dem', 'French_dem', 'English_dem'],
    'Health': ['Nutrition_dem', 'Fitness & Excercise_dem', 'Wellness_dem'],
    'Sports': ['Tennis_dem', 'Football_dem', 'Basketball_dem', 'Yoga_dem', 'Baseball_dem', 'Gymnastic_dem'],
    'Food': ['Cooking_dem', 'Baking_dem', 'Grilling_dem', 'Meal planning_dem', 'Sautéing_dem'],
    'Technology': ['Programming_dem', 'Graphic design_dem', 'Data Analysis_dem', 'Photoshop_dem', 'Social Media_dem'],
    'Photo': ['Camera handling_dem', 'Photo editing_dem', 'Lighting_dem', 'Landscape photography_dem', 'Portrait photography_dem', 'Image processing_dem'],
    'Video': ['Video editing_dem', 'Film making_dem', 'Animation_dem', 'Motion graphics_dem', 'Visual effects_dem']
}

# %%
# Initialize a list to store the matched skills for each domain sample
# Iterate through each domain sample in random_skill_samples
# Initialize an empty list to store the matched skills for the current sample
# Iterate through each skill domain in the current sample
# Retrieve the matching skills from skills_dict and extend the matched_skills list
# Append the matched skills for the current sample to the matched_skills_samples list


matched_skills_samples = []

for sample in random_skill_samples:
    matched_skills = []
    for skill_domain in sample:
        matched_skills.extend(skills_dict.get(skill_domain, []))
    matched_skills_samples.append(matched_skills)
    
    
print(matched_skills_samples)
# Out:
# [['Cooking_dem', 'Baking_dem', 'Grilling_dem', 'Meal planning_dem', 'Sautéing_dem', 'Drawing_dem', 'Painting_dem', 'Sculpture_dem', 'Print making_dem', 'Poetry_dem', 'Farming_dem', 'Fishery_dem', 'Gardening_dem'], ['Piano_dem', 'Guitar_dem', 'Drumming_dem', 'Trumpet_dem', 'Composing_dem', 'Cooking_dem', 'Baking_dem', 'Grilling_dem', 'Meal planning_dem', 'Sautéing_dem', 'Farming_dem', 'Fishery_dem', 'Gardening_dem', 'Camera handling_dem', 'Photo editing_dem', 'Lighting_dem', 'Landscape photography_dem', 'Portrait photography_dem', 'Image processing_dem', 'Nutrition_dem', 'Fitness & Excercise_dem', 'Wellness_dem'], ['Pet grooming_dem', 'Pet training_dem', 'Programming_dem', 'Graphic design_dem', 'Data Analysis_dem', 'Photoshop_dem', 'Social Media_dem', 'Script writing_dem', 'Play writing_dem', 'Poetry writing_dem', 'Caligraphy_dem', 'Blogging_dem', 'Journalism_dem'], ['Make-up_dem', 'Facials_dem', 'Pedicure & Manicure_dem', 'Hair care_dem', 'Piano_dem', 'Guitar_dem', 'Drumming_dem', 'T
# ...

# %%
Matched_skills_df = pd.DataFrame({"Matched_skills_samples": matched_skills_samples})
Matched_skills_df
# Out:
#                                  Matched_skills_samples
# 0     [Cooking_dem, Baking_dem, Grilling_dem, Meal p...
# 1     [Piano_dem, Guitar_dem, Drumming_dem, Trumpet_...
# 2     [Pet grooming_dem, Pet training_dem, Programmi...
# 3     [Make-up_dem, Facials_dem, Pedicure & Manicure...
# 4     [Video editing_dem, Film making_dem, Animation...
# ...                                                 ...
# 9995  [Make-up_dem, Facials_dem, Pedicure & Manicure...
# 9996  [Nutrition_dem, Fitness & Excercise_dem, Welln...
# 9997  [Camera handling_dem, Photo editing_dem, Light...
# 9998  [Nutrition_dem, Fitness & Excercise_dem, Welln...
# 9999  [Script writing_dem, Play writing_dem, Poetry ...
#
# [10000 rows x 1 columns]

# %%
# Define the columns of the final data frame to then fill them with input 
# Skill interests
# Define demanded skill categories as lists
Farming_dem = []
Fishery_dem = []
Gardening_dem = []
Pet_grooming_dem = []
Pet_training_dem = []
Drawing_dem = []
Painting_dem = []
Sculpture_dem = []
Print_making_dem = []
Poetry_dem = []
Make_up_dem = []
Facials_dem = []
Pedicure_and_Manicure_dem = []
Hair_care_dem = []
Ballet_dem = []
Tap_dance_dem = []
Jazz_dance_dem = []
Salsa_dem = []
Ballroom_dance_dem = []
Piano_dem = []
Guitar_dem = []
Drumming_dem = []
Trumpet_dem = []
Composing_dem = []
Script_writing_dem = []
Play_writing_dem = []
Poetry_writing_dem = []
Caligraphy_dem = []
Blogging_dem = []
Journalism_dem = []
German_dem = []
Spanish_dem = []
Arabic_dem = []
French_dem = []
English_dem = []
Nutrition_dem = []
Fitness_and_Excercise_dem = []
Wellness_dem = []
Tennis_dem = []
Football_dem = []
Basketball_dem = []
Yoga_dem = []
Baseball_dem = []
Gymnastic_dem = []
Cooking_dem = []
Baking_dem = []
Grilling_dem = []
Meal_planning_dem = []
Sautéing_dem = []
Programming_dem = []
Graphic_design_dem = []
Data_Analysis_dem = []
Photoshop_dem = []
Social_Media_dem = []
Camera_handling_dem = []
Photo_editing_dem = []
Lighting_dem = []
Landscape_photography_dem = []
Portrait_photography_dem = []
Image_processing_dem = []
Video_editing_dem = []
Film_making_dem = []
Animation_dem = []
Motion_graphics_dem = []
Visual_effects_dem = []

# %%
# Skill Interests
skill_table= {
"Farming_dem": Farming_dem,
"Fishery_dem": Fishery_dem,
"Gardening_dem": Gardening_dem,
"Pet grooming_dem": Pet_grooming_dem,
"Pet training_dem": Pet_training_dem,
"Drawing_dem": Drawing_dem,
"Painting_dem": Painting_dem,
"Sculpture_dem": Sculpture_dem,
"Print making_dem": Print_making_dem,
"Poetry_dem": Poetry_dem,
"Make-up_dem": Make_up_dem,
"Facials_dem": Facials_dem,
"Pedicure & Manicure_dem": Pedicure_and_Manicure_dem,
"Hair care_dem": Hair_care_dem,
"Ballet_dem": Ballet_dem,
"Tap dance_dem": Tap_dance_dem,
"Jazz dance_dem": Jazz_dance_dem,
"Salsa_dem": Salsa_dem,
"Ballroom dance_dem": Ballroom_dance_dem,
"Piano_dem": Piano_dem,
"Guitar_dem": Guitar_dem,
"Drumming_dem": Drumming_dem,
"Trumpet_dem": Trumpet_dem,
"Composing_dem": Composing_dem,
"Script writing_dem": Script_writing_dem,
"Play writing_dem": Play_writing_dem,
"Poetry writing_dem": Poetry_writing_dem,
"Caligraphy_dem": Caligraphy_dem,
"Blogging_dem": Blogging_dem,
"Journalism_dem": Journalism_dem,
"German_dem": German_dem,
"Spanish_dem": Spanish_dem,
"Arabic_dem": Arabic_dem,
"French_dem": French_dem,
"English_dem": English_dem,
"Nutrition_dem": Nutrition_dem,
"Fitness & Excercise_dem": Fitness_and_Excercise_dem,
"Wellness_dem": Wellness_dem,
"Tennis_dem": Tennis_dem,
"Football_dem": Football_dem,
"Basketball_dem": Basketball_dem,
"Yoga_dem": Yoga_dem,
"Baseball_dem": Baseball_dem,
"Gymnastic_dem": Gymnastic_dem,
"Cooking_dem": Cooking_dem,
"Baking_dem": Baking_dem,
"Grilling_dem": Grilling_dem,
"Meal planning_dem": Meal_planning_dem,
"Sautéing_dem": Sautéing_dem,
"Programming_dem": Programming_dem,
"Graphic design_dem": Graphic_design_dem,
"Data Analysis_dem": Data_Analysis_dem,
"Photoshop_dem": Photoshop_dem,
"Social Media_dem": Social_Media_dem,
"Camera handling_dem": Camera_handling_dem,
"Photo editing_dem": Photo_editing_dem,
"Lighting_dem": Lighting_dem,
"Landscape photography_dem": Landscape_photography_dem,
"Portrait photography_dem": Portrait_photography_dem,
"Image processing_dem": Image_processing_dem,
"Video editing_dem": Video_editing_dem,
"Film making_dem": Film_making_dem,
"Animation_dem": Animation_dem,
"Motion graphics_dem": Motion_graphics_dem,
"Visual effects_dem": Visual_effects_dem
}

Skills_Demanded = pd.DataFrame(skill_table)

Skills_Demanded.head()
# Out:
# Empty DataFrame
# ...

# %%
concatenated_df = pd.concat([Skills_Demanded, Matched_skills_df], axis=1)
concatenated_df
# Out:
#       Farming_dem  Fishery_dem  Gardening_dem  Pet grooming_dem  \
# 0             NaN          NaN            NaN               NaN
# 1             NaN          NaN            NaN               NaN
# 2             NaN          NaN            NaN               NaN
# 3             NaN          NaN            NaN               NaN
# 4             NaN          NaN            NaN               NaN
# ...           ...          ...            ...               ...
# 9995          NaN          NaN            NaN               NaN
# 9996          NaN          NaN            NaN               NaN
# 9997          NaN          NaN            NaN               NaN
# 9998          NaN          NaN            NaN               NaN
# 9999          NaN          NaN            NaN               NaN
#
#       Pet training_dem  Drawing_dem  Painting_dem  Sculpture_dem  \
# 0                  NaN          NaN           NaN            NaN
# ...

# %%
# Randomly select a value from possible_levels with a normal distribution to 
# fill the columns (where a person has a skill interest) with skill levels
# Define possible skill levels
# Assumption: Usually people tend to seek for people that are rather experienced to teach them skills
# Iterate over each row in the DataFrame
# Extract the list of matched skills from the current row
# Iterate over each column in the DataFrame
# Check if the column name matches any of the skills in matched_skills
# Define parameters for the normal distribution
# Generate random index from a normal distribution
# Ensure the index falls within the range of possible indices
# Select the skill level corresponding to the generated index
# Assign the randomly selected value to the corresponding cell in the matched headline

for index, row in concatenated_df.iterrows():
    matched_skills = row['Matched_skills_samples']
    
    for column in concatenated_df.columns:
        if column in matched_skills:
            concatenated_df.at[index, column] = 1  
        else:
            concatenated_df.at[index, column] = 0

# %%
concatenated_df = concatenated_df.astype(int)
concatenated_df
# Out:
#       Farming_dem  Fishery_dem  Gardening_dem  Pet grooming_dem  \
# 0               1            1              1                 0
# 1               1            1              1                 0
# 2               0            0              0                 1
# 3               0            0              0                 0
# 4               0            0              0                 0
# ...           ...          ...            ...               ...
# 9995            0            0              0                 0
# 9996            0            0              0                 0
# 9997            0            0              0                 0
# 9998            0            0              0                 0
# 9999            0            0              0                 0
#
#       Pet training_dem  Drawing_dem  Painting_dem  Sculpture_dem  \
# 0                    0            1             1              1
# ...

# %%
# create clean dataframe
Skill_Exchange_Demanded = concatenated_df.drop(columns=["Matched_skills_samples"])
Skill_Exchange_Demanded
# Out:
#       Farming_dem  Fishery_dem  Gardening_dem  Pet grooming_dem  \
# 0               1            1              1                 0
# 1               1            1              1                 0
# 2               0            0              0                 1
# 3               0            0              0                 0
# 4               0            0              0                 0
# ...           ...          ...            ...               ...
# 9995            0            0              0                 0
# 9996            0            0              0                 0
# 9997            0            0              0                 0
# 9998            0            0              0                 0
# 9999            0            0              0                 0
#
#       Pet training_dem  Drawing_dem  Painting_dem  Sculpture_dem  \
# 0                    0            1             1              1
# ...

# %%
Skill_Exchange_Demanded.to_csv("Skill_Exchange_Demanded.csv", index=False)
