# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Johannes\Documents\ws24-skillswap\DS\01_Notebooks\01_Synthetic_Data_Set\Skillswap_Data_Raw.csv')

df.head()
# Out:
#   First_Name                            EMail  Age  Gender  \
# 0      Tymon          tymon.giolitti@1und1.de   26    Male
# 1     Benito        benito.guichard@gmail.com   23  Female
# 2       Eryk         eryk.renault@t-online.de   30  Female
# 3     Graeme    graeme.pizziol@protonmail.com   30  Female
# 4   Antonino  antonino.miranda@protonmail.com   25    Male
#
#   Location_Preferences   Latitude  Longitude  Country    City  \
# 0      Local or Remote  52.425343  13.695938  Germany  Berlin
# 1      Local or Remote  52.472685  13.562493  Germany  Berlin
# 2      Local or Remote  52.651681  13.713052  Germany  Berlin
# 3      Local or Remote  52.459891  13.192676  Germany  Berlin
# 4      Local or Remote  52.567783  13.705778  Germany  Berlin
#
#                            Languages_Preferred  ... Sports Food Technology  \
# 0                        ['Punjabi', 'Polish']  ...    NaN  NaN        NaN
# 1                     ['Portuguese', 'Arabic']  ...    NaN  NaN        NaN
# 2                                   ['French']  ...    NaN  NaN       10.0
# 3                         ['Mandarin Chinese']  ...    NaN  NaN        NaN
# 4  ['Arabic', 'Spanish', 'Punjabi', 'Turkish']  ...    NaN  NaN        NaN
#
#   Photo Video           Usability   Speed_Performance Feature_Satisfaction  \
# 0   NaN   NaN  Neutral or Average        Dissatisfied         Dissatisfied
# 1   NaN   NaN           Satisfied      Very Satisfied   Neutral or Average
# 2   NaN   NaN           Satisfied           Satisfied         Dissatisfied
# 3   NaN   NaN      Very Satisfied  Neutral or Average            Satisfied
# 4   NaN   NaN  Neutral or Average      Very Satisfied   Neutral or Average
#
#   Security_Satisfaction    Customer_Support
# 0        Very Satisfied  Neutral or Average
# 1             Satisfied           Satisfied
# 2        Very Satisfied   Very Dissatisfied
# 3             Satisfied      Very Satisfied
# 4    Neutral or Average  Neutral or Average
#
# [5 rows x 255 columns]

# %%
# Label Data with Activity Status

df['Activity_Status'] = ""

average_sum_skills = df['Sum_Skills_Off'].mean()
df['Sum_Skills_Off_ab_avg'] = df['Sum_Skills_Off'].apply(lambda x: 1 if x > average_sum_skills else 0)

for index, row in df.iterrows():
    if row['Last_Seen'] in ["Recently", "Today", "Yesterday", "Within a Week"] and \
            row['Response_Time'] in ["Within 24 hours", "Within a week"] and \
            row['Sum_Skills_Off_ab_avg'] == 1:
        df.at[index, 'Activity_Status'] = "Swapper"
    elif row['Last_Seen'] in ["Recently", "Today", "Yesterday", "Within a Week"] and \
            row['Response_Time'] in ["Within 24 hours", "Within a week"] and \
            row['Sum_Skills_Off_ab_avg'] == 0:
        df.at[index, 'Activity_Status'] = "Active User"
    elif row['Last_Seen'] == "Within a Month" or row['Response_Time'] == "Within a month":
        df.at[index, 'Activity_Status'] = "Occasional User"
    elif row['Last_Seen'] == "Over a Month Ago" or row['Response_Time'] == "More than a month":
        df.at[index, 'Activity_Status'] = "Inactive"
    else:
        df.at[index, 'Activity_Status'] = pd.NA 

df.head()
# Out:
#   First_Name                            EMail  Age  Gender  \
# 0      Tymon          tymon.giolitti@1und1.de   26    Male
# 1     Benito        benito.guichard@gmail.com   23  Female
# 2       Eryk         eryk.renault@t-online.de   30  Female
# 3     Graeme    graeme.pizziol@protonmail.com   30  Female
# 4   Antonino  antonino.miranda@protonmail.com   25    Male
#
#   Location_Preferences   Latitude  Longitude  Country    City  \
# 0      Local or Remote  52.425343  13.695938  Germany  Berlin
# 1      Local or Remote  52.472685  13.562493  Germany  Berlin
# 2      Local or Remote  52.651681  13.713052  Germany  Berlin
# 3      Local or Remote  52.459891  13.192676  Germany  Berlin
# 4      Local or Remote  52.567783  13.705778  Germany  Berlin
#
#                            Languages_Preferred  ... Technology Photo Video  \
# 0                        ['Punjabi', 'Polish']  ...        NaN   NaN   NaN
# 1                     ['Portuguese', 'Arabic']  ...        NaN   NaN   NaN
# 2                                   ['French']  ...       10.0   NaN   NaN
# 3                         ['Mandarin Chinese']  ...        NaN   NaN   NaN
# 4  ['Arabic', 'Spanish', 'Punjabi', 'Turkish']  ...        NaN   NaN   NaN
#
#             Usability   Speed_Performance Feature_Satisfaction  \
# 0  Neutral or Average        Dissatisfied         Dissatisfied
# 1           Satisfied      Very Satisfied   Neutral or Average
# 2           Satisfied           Satisfied         Dissatisfied
# 3      Very Satisfied  Neutral or Average            Satisfied
# 4  Neutral or Average      Very Satisfied   Neutral or Average
#
#   Security_Satisfaction    Customer_Support  Activity_Status  \
# 0        Very Satisfied  Neutral or Average          Swapper
# 1             Satisfied           Satisfied  Occasional User
# 2        Very Satisfied   Very Dissatisfied          Swapper
# 3             Satisfied      Very Satisfied         Inactive
# 4    Neutral or Average  Neutral or Average          Swapper
#
#   Sum_Skills_Off_ab_avg
# 0                     1
# 1                     0
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 257 columns]

# %%
# Check NA Values
empty_values = df['Activity_Status'].isna().sum()

print("Number of empty values in the 'Activity_Status' column:", empty_values)
# Out:
# Number of empty values in the 'Activity_Status' column: 0

# %%
# Count unique values
activity_status_counts = df['Activity_Status'].value_counts()

print("Count of unique values in the 'Activity_Status' column:")
print(activity_status_counts)
# Out:
# Count of unique values in the 'Activity_Status' column:
# Activity_Status
# Occasional User    264
# Swapper            233
# Active User        208
# Inactive            95
# Name: count, dtype: int64

# %%
df.to_csv('Skillswap_Data_Activity_Status.csv', index=False)
