# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df1 = pd.read_csv(r'C:\Users\Johannes\Documents\Uni\Master\Tech_Labs\ws24-skillswap\DS\01_Notebooks\01_Synthetic_Data_Set\Skillswap_Data_Labeled.csv')

df1.head()
# Out:
#   First_Name                       EMail  Age  Gender Location_Preferences  \
# 0     Łukasz        łukasz.sezgin@gmx.de   25  Female      Local or Remote
# 1     Bianca  bianca.herrmann@icloud.com   25    Male          Remote Only
# 2      Adlan  adlan.jacobi jäckel@gmx.de   21  Female      Local or Remote
# 3     Emilio       emilio.alemdar@web.de   28  Female      Local or Remote
# 4   Valentin  valentin.çetin@t-online.de   31    Male      Local or Remote
#
#     Latitude  Longitude  Country    City  \
# 0  52.376172  13.581876  Germany  Berlin
# 1  52.644114  13.648641  Germany  Berlin
# 2  52.531250  13.125491  Germany  Berlin
# 3  52.450986  13.199572  Germany  Berlin
# 4  52.599578  13.277228  Germany  Berlin
#
#                                  Languages_Preferred  ... Technology Photo  \
# 0  ['German', 'Portuguese', 'Russian', 'Mandarin ...  ...        NaN   NaN
# 1  ['Mandarin Chinese', 'Turkish', 'Romanian', 'J...  ...        NaN  17.0
# 2                                        ['Spanish']  ...        NaN   7.0
# 3      ['German', 'Spanish', 'Portuguese', 'Polish']  ...        NaN   NaN
# 4           ['Mandarin Chinese', 'Hindi', 'Turkish']  ...        NaN   NaN
#
#   Video           Usability   Speed_Performance Feature_Satisfaction  \
# 0   NaN      Very Satisfied        Dissatisfied       Very Satisfied
# 1   NaN      Very Satisfied        Dissatisfied    Very Dissatisfied
# 2   NaN           Satisfied  Neutral or Average            Satisfied
# 3   NaN           Satisfied           Satisfied       Very Satisfied
# 4   NaN  Neutral or Average      Very Satisfied   Neutral or Average
#
#   Security_Satisfaction    Customer_Support  Activity_Status  \
# 0     Very Dissatisfied        Dissatisfied      Active User
# 1             Satisfied  Neutral or Average         Inactive
# 2     Very Dissatisfied  Neutral or Average      Active User
# 3    Neutral or Average      Very Satisfied  Occasional User
# 4     Very Dissatisfied  Neutral or Average          Swapper
#
#   Sum_Skills_Off_ab_avg
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
#
# [5 rows x 256 columns]

# %%
skill_domains = [
    "Agriculture",
    "Animal Care",
    "Art",
    "Beauty",
    "Dance",
    "Music",
    "Writing",
    "Language",
    "Health",
    "Sports",
    "Food",
    "Technology",
    "Photo",
    "Video"
]

filtered_columns = [col for col in df1.columns if col in skill_domains or col == "Sum_Skills_Off"]

filtered_df = df1[filtered_columns]
filtered_df.head()
# Out:
#    Sum_Skills_Off  Agriculture  Animal Care  Art  Beauty  Dance  Music  \
# 0             5.0          NaN          NaN  NaN     NaN    NaN    NaN
# 1            17.0          NaN          NaN  NaN     NaN    NaN    NaN
# 2             7.0          NaN          NaN  NaN     NaN    NaN    NaN
# 3             0.0          NaN          NaN  NaN     NaN    NaN    NaN
# 4            14.0          NaN          NaN  NaN     NaN   14.0    NaN
#
#    Writing  Language  Health  Sports  Food  Technology  Photo  Video
# 0      5.0       NaN     NaN     NaN   NaN         NaN    NaN    NaN
# 1      NaN       NaN     NaN     NaN   NaN         NaN   17.0    NaN
# 2      NaN       NaN     NaN     NaN   NaN         NaN    7.0    NaN
# 3      NaN       NaN     NaN     0.0   NaN         NaN    NaN    NaN
# 4      NaN       NaN     NaN     NaN   NaN         NaN    NaN    NaN
